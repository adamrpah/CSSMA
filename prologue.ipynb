# %% [markdown]
# # Computational Social Science: Methods and Applications
#
# ## First of all, Welcome!
#
# The research world you are entering is a markedly different one than 20 years ago. What was once supplemental, the computer, has become ubiquitous throughout research. Further, the need for programming as a skill, either to increase productivity, enhance reproducibility, or unlock innovative research programmes, has moved from nearly non-existent to almost expected.
#
# This course will focus on developing our understanding of text as data and computational approaches to modeling and using it in our research. Through primary research literature and hands-on work we will develop both an understanding and skill at executing research techniques in this area.
#
# ## Class style
#
# During class time we will use active learning, coding together and solving exercises with short periods of lecture and discussion. I structure the class because the act of 'programming' is incidental to the goal of learning how to conduct research in these areas. In class, I will go over the 'big idea' and discuss implementation (making sure we all start and end at the same place of understanding.
#
# ## Week 1. Course Overview
# 1. [Course Introduction](presentations/intro_lecture.pptx)
# 2. [Introduction to Git](presentations/Intro2Git.pptx)
# 3. [Introduction to Jupyter Notebook](presentations/intro2Jupyter.pptx)
#
#
# ## Week 2. NLP Fundamentals
#
# 1. [Fundamentals of text processing](lessons/text/Text-processing.ipynb)
#
# ## Week 3. NLP Fundamentals
#
# 1. [Fundamentals of text processing](lessons/text/Text-processing.ipynb)
#
# ## Week 4. Information Theory
#
# 1. [Information theory and change](lessons/text/Information-Theory.ipynb)
# 2. [Null models and bootstrapping](lessons/networks/Null-models.ipynb)
#
# ## Week 5. Sentiment Analysis
#
# 1. [Sentiment dictionary analysis](lessons/text/Sentiment-Analysis.ipynb)
#
# ## Week 6. Machine Learning Fundamentals
#
# 1. [Learned sentiment](lessons/text/Learned-Sentiment.ipynb)
#
#
# ## Week 7. Machine Learning Pt. 2
#
# 1. [NER and Disambiguation](lessons/text/ner.ipynb)
#
# ## Week 8. Machine Learning Pt. 3
#
# ## Week 9. Topic Modelling
#
# 1. [Topic maps](lessons/text/Topic-mapping.ipynb)
#
# ## Week 10. Topic Modelling -- Open Alex Project
# 1. [OpenAlex](lessons/text/open_alex.ipynb)
#
# ## Week 11. Topic Modelling Alternatives
#
# ## Week 12. Neural Networks and LLMs
#
# ## Week 13. LLM Practice
#
# ## Week 14. Text vectors and concept universality
# 1. [Word embeddings](lessons/text/Word2Vec.ipynb)
