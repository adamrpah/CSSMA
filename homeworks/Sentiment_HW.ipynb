# %% [markdown]
# # Sentiment Homework

# %% [markdown]
# # Machine Learning Training
#
# For your homework you will continue to work with scikit learn and the PerSent data. You will preprocess the data and train 3 different classification models (of your choice) and conduct parameter optimization.
#
# 1. Preprocess the PerSent data
# 2. Pick 3 classification models
# 3. Optimize the models and compare the classification performance
