# %% [markdown]
# # NLTK Homework
#
# Last week you compared the word usage in the "Tragedy of Macbeth" and "All's Well that Ends Well" using the string processing techniques that we could execute with standard Python. This week you need to replicate last week's homework but using NLTK and implementing a full pre-processing pipeline (cleaning, tokenization, stemming, and stop-word removal) before calculating and graphing the rank-frequency plots. This homework requires:
#
# 1. Writing a NLTK based pre-processing pipeline
# 2. Produce Bag of Words for "The Tragedy of Macbeth" and "All's Well that Ends Well" using the NLTK pre-processing pipeline
# 3. Calculate and plot the [rank-frequency](https://en.wikipedia.org/wiki/Rank–size_distribution) plot for both of the plays on the same graph.
