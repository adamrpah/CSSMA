# %% [markdown]
# # Networks
#
# In 2020, it is difficult to find someone who doesn't have some idea of what a network is because the internet and social media platforms have brought them so clearly into focus. When I say network people immediately think of things like facebook and the connections that it brings worldwide.
#
# But there is a lot more to networks than that.

# %% [markdown]
# Full-stop. A network graph is simply a mathematical model that is composed of vertices and edges, $G = (V, E)$
#
# <img src='../../images/basic_network.png'>
#
# This mathematical model facilitates the analysis of topology and interactions between entites. The first usage of a network was by Euler in the 1700s to solve a long-standing riddle concerning the [traversal of bridges in Konigsberg](https://en.wikipedia.org/wiki/Seven_Bridges_of_Königsberg). His insight may seem extremely simple, it involved the reduction of a physical reality to a mathematical object
#
# <img src='../../images/konigsberg_bridge.png'>
#
# but it allowed for a mathematical proof to the riddle that was not easily achieved with other approaches.

# %% [markdown]
# # Analyzing networks with Python
#
# There are primarily two packages you can use when you want to undertake network analysis. The first package is **NetworkX**, which has been under development for almost a decade now. The second is **graph-tool**, which is younger. graph-tool is significantly faster than NetworkX because most of the package is implemented in C++. However, this makes installation of the package more difficult.
#
# At the start of class we installed `graph-tool` and given the speed advantages and built-in statistical modelling we will use it in class.

# %%
# !conda config --add channels conda-forge
# Out:
# Warning: 'conda-forge' already in 'channels' list, moving to the top

# %%
# !conda config --set channel_priority strict

# %%
# !conda install graph-tool -y
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - conda-forge
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.5.0
#     latest version: 25.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - graph-tool
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _x86_64-microarch-level-4  |           2_zen4           8 KB  conda-forge
#     at-spi2-atk-2.38.0         |       h0630a04_3         332 KB  conda-forge
#     at-spi2-core-2.40.3        |       h0630a04_0         643 KB  conda-forge
#     atk-1.0-2.38.0             |       h04ea711_2         348 KB  conda-forge
#     blas-2.136                 |         openblas          17 KB  conda-forge
#     blas-devel-3.9.0           |36_h1ea3ea9_openblas          17 KB  conda-forge
#     c-ares-1.34.5              |       hb9d3cd8_0         202 KB  conda-forge
#     c-blosc2-2.15.2            |       h68e2383_0         334 KB  conda-forge
#     ca-certificates-2025.10.5  |       hbd8a1cb_0         152 KB  conda-forge
#     cairo-1.18.4               |       h3394656_0         955 KB  conda-forge
#     cairomm-1.16.2             |       ha770c72_1          14 KB  conda-forge
#     cairomm-1.16-1.16.2        |       h7e731d7_1         117 KB  conda-forge
#     certifi-2025.10.5          |     pyhd8ed1ab_0         156 KB  conda-forge
#     curl-8.14.1                |       h332b0f4_0         176 KB  conda-forge
#     dbus-1.16.2                |       h3c4dab8_0         428 KB  conda-forge
#     epoxy-1.5.10               |       hb03c661_2         402 KB  conda-forge
#     expat-2.7.1                |       hecca717_0         138 KB  conda-forge
#     fontconfig-2.15.0          |       h7e30c49_1         259 KB  conda-forge
#     freetype-2.14.1            |       ha770c72_0         169 KB  conda-forge
#     gdk-pixbuf-2.42.12         |       h2b0a6b4_3         566 KB  conda-forge
#     glib-tools-2.84.3          |       hf516916_0         114 KB  conda-forge
#     graph-tool-2.98            |py311h2cebea5_400          42 KB  conda-forge
#     graph-tool-base-2.98       |py311h78e300f_400        58.9 MB  conda-forge
#     gtk3-3.24.43               |       h021d004_3         5.3 MB  conda-forge
#     harfbuzz-11.3.3            |       hbb57e21_0         1.7 MB  conda-forge
#     hicolor-icon-theme-0.17    |       ha770c72_2          14 KB  conda-forge
#     icu-75.1                   |       he02047a_0        11.6 MB  conda-forge
#     imagecodecs-2024.6.1       |  py311h732c098_3         2.0 MB  conda-forge
#     lcms2-2.17                 |       h717163a_0         242 KB  conda-forge
#     libavif16-1.2.1            |       hbb36593_2         135 KB  conda-forge
#     libblas-3.9.0              |36_h4a7cf45_openblas          17 KB  conda-forge
#     libboost-1.86.0            |       hed09d94_4         2.8 MB  conda-forge
#     libboost-python-1.86.0     |  py311h1d5f577_4         118 KB  conda-forge
#     libcblas-3.9.0             |36_h0358290_openblas          17 KB  conda-forge
#     libcups-2.3.3              |       hb8b1518_5         4.3 MB  conda-forge
#     libcurl-8.14.1             |       h332b0f4_0         439 KB  conda-forge
#     libdeflate-1.21            |       h4bc722e_0          69 KB  conda-forge
#     libdrm-2.4.125             |       hb03c661_1         304 KB  conda-forge
#     libegl-1.7.0               |       ha4b6fd6_2          44 KB  conda-forge
#     libegl-devel-1.7.0         |       ha4b6fd6_2          30 KB  conda-forge
#     libexpat-2.7.1             |       hecca717_0          73 KB  conda-forge
#     libffi-3.4.6               |       h2dba641_1          56 KB  conda-forge
#     libfreetype-2.14.1         |       ha770c72_0           7 KB  conda-forge
#     libfreetype6-2.14.1        |       h73754d4_0         378 KB  conda-forge
#     libgcc-15.2.0              |       h767d61c_7         803 KB  conda-forge
#     libgcc-ng-15.2.0           |       h69a702a_7          29 KB  conda-forge
#     libgfortran-15.2.0         |       h69a702a_7          29 KB  conda-forge
#     libgfortran-ng-15.2.0      |       h69a702a_7          29 KB  conda-forge
#     libgfortran5-15.2.0        |       hcd61629_7         1.5 MB  conda-forge
#     libgirepository-1.84.0     |       h61e2d6e_2         304 KB  conda-forge
#     libgit2-1.9.1              |       h014eb84_0        1007 KB  conda-forge
#     libgl-1.7.0                |       ha4b6fd6_2         132 KB  conda-forge
#     libgl-devel-1.7.0          |       ha4b6fd6_2         111 KB  conda-forge
#     libglib-2.84.3             |       hf39c6af_0         3.8 MB  conda-forge
#     libglvnd-1.7.0             |       ha4b6fd6_2         129 KB  conda-forge
#     libglx-1.7.0               |       ha4b6fd6_2          74 KB  conda-forge
#     libglx-devel-1.7.0         |       ha4b6fd6_2          26 KB  conda-forge
#     libgomp-15.2.0             |       h767d61c_7         437 KB  conda-forge
#     libiconv-1.18              |       h3b78370_2         772 KB  conda-forge
#     libjpeg-turbo-3.1.0        |       hb9d3cd8_0         614 KB  conda-forge
#     liblapack-3.9.0            |36_h47877c9_openblas          17 KB  conda-forge
#     liblapacke-3.9.0           |36_h6ae95b6_openblas          17 KB  conda-forge
#     liblzma-5.8.1              |       hb9d3cd8_2         110 KB  conda-forge
#     liblzma-devel-5.8.1        |       hb9d3cd8_2         430 KB  conda-forge
#     libnghttp2-1.67.0          |       had1ee68_0         651 KB  conda-forge
#     libopenblas-0.3.30         |pthreads_h94d23a6_2         5.7 MB  conda-forge
#     libpciaccess-0.18          |       hb9d3cd8_0          28 KB  conda-forge
#     libpng-1.6.50              |       h421ea60_1         310 KB  conda-forge
#     librsvg-2.58.4             |       he92a37e_3         6.2 MB  conda-forge
#     libssh2-1.11.1             |       hcf80075_0         298 KB  conda-forge
#     libstdcxx-15.2.0           |       h8f9b012_7         3.7 MB  conda-forge
#     libstdcxx-ng-15.2.0        |       h4852527_7          29 KB  conda-forge
#     libtiff-4.7.0              |       h6565414_0         418 KB  conda-forge
#     libxcb-1.17.0              |       h8a09558_0         387 KB  conda-forge
#     libxkbcommon-1.7.0         |       h2c5496b_1         579 KB  conda-forge
#     libxml2-2.13.8             |       h04c0eec_1         682 KB  conda-forge
#     nodejs-20.17.0             |       hc55a1b2_0        16.4 MB  conda-forge
#     openblas-0.3.30            |pthreads_h6ec200e_2         5.8 MB  conda-forge
#     openjpeg-2.5.3             |       h55fea9a_1         349 KB  conda-forge
#     openssl-3.5.4              |       h26f9b46_0         3.0 MB  conda-forge
#     pango-1.56.4               |       hadf4263_0         445 KB  conda-forge
#     pcre2-10.45                |       hc749103_0         1.1 MB  conda-forge
#     pillow-11.0.0              |  py311h49e9ac3_0        40.5 MB  conda-forge
#     pixman-0.46.4              |       h54a6638_1         440 KB  conda-forge
#     pycairo-1.28.0             |  py311hc1a9592_1         115 KB  conda-forge
#     pygobject-3.50.0           |  py311hba7ce5e_1         441 KB  conda-forge
#     r-base-4.3.3               |      h65010dc_18        24.5 MB  conda-forge
#     r-gert-2.1.5               |    r43h5e22a44_0         255 KB  conda-forge
#     r-ragg-1.5.0               |    r43h9f1dc4d_0         576 KB  conda-forge
#     r-stringi-1.8.7            |    r43h3c328a7_0         884 KB  conda-forge
#     r-textshaping-1.0.1        |    r43h16f7c1a_0         180 KB  conda-forge
#     sigcpp-3.0-3.6.0           |       h59595ed_0          59 KB  conda-forge
#     snappy-1.2.2               |       h03e3b7b_0          45 KB  conda-forge
#     sparsehash-2.0.4           |       hcb278e6_1          84 KB  conda-forge
#     svt-av1-3.0.2              |       h5888daf_0         2.6 MB  conda-forge
#     wayland-1.24.0             |       h3e06ad9_0         323 KB  conda-forge
#     xkeyboard-config-2.46      |       hb03c661_0         388 KB  conda-forge
#     xorg-libice-1.1.2          |       hb9d3cd8_0          57 KB  conda-forge
#     xorg-libsm-1.2.6           |       he73a12e_0          27 KB  conda-forge
#     xorg-libx11-1.8.12         |       h4f16b4b_0         816 KB  conda-forge
#     xorg-libxcomposite-0.4.6   |       hb9d3cd8_2          13 KB  conda-forge
#     xorg-libxcursor-1.2.3      |       hb9d3cd8_0          32 KB  conda-forge
#     xorg-libxdamage-1.1.6      |       hb9d3cd8_0          13 KB  conda-forge
#     xorg-libxext-1.3.6         |       hb9d3cd8_0          49 KB  conda-forge
#     xorg-libxfixes-6.0.2       |       hb03c661_0          20 KB  conda-forge
#     xorg-libxi-1.8.2           |       hb9d3cd8_0          46 KB  conda-forge
#     xorg-libxinerama-1.1.5     |       h5888daf_1          14 KB  conda-forge
#     xorg-libxrandr-1.5.4       |       hb9d3cd8_0          29 KB  conda-forge
#     xorg-libxrender-0.9.12     |       hb9d3cd8_0          32 KB  conda-forge
#     xorg-libxtst-1.2.5         |       hb9d3cd8_3          32 KB  conda-forge
#     xorg-libxxf86vm-1.1.6      |       hb9d3cd8_0          17 KB  conda-forge
#     xorg-xorgproto-2024.1      |       hb9d3cd8_1         552 KB  conda-forge
#     xz-5.8.1                   |       hbcc6ac9_2          23 KB  conda-forge
#     xz-gpl-tools-5.8.1         |       hbcc6ac9_2          33 KB  conda-forge
#     xz-tools-5.8.1             |       hb9d3cd8_2          94 KB  conda-forge
#     zlib-ng-2.2.5              |       hde8ca8f_0         108 KB  conda-forge
#     zstandard-0.25.0           |  py311haee01d2_0         456 KB  conda-forge
#     zstd-1.5.7                 |       hb8e6e7a_2         554 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       224.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   _x86_64-microarch~ conda-forge/noarch::_x86_64-microarch-level-4-2_zen4
#   at-spi2-atk        conda-forge/linux-64::at-spi2-atk-2.38.0-h0630a04_3
#   at-spi2-core       conda-forge/linux-64::at-spi2-core-2.40.3-h0630a04_0
#   atk-1.0            conda-forge/linux-64::atk-1.0-2.38.0-h04ea711_2
#   cairomm            conda-forge/linux-64::cairomm-1.16.2-ha770c72_1
#   cairomm-1.16       conda-forge/linux-64::cairomm-1.16-1.16.2-h7e731d7_1
#   dbus               conda-forge/linux-64::dbus-1.16.2-h3c4dab8_0
#   epoxy              conda-forge/linux-64::epoxy-1.5.10-hb03c661_2
#   gdk-pixbuf         conda-forge/linux-64::gdk-pixbuf-2.42.12-h2b0a6b4_3
#   glib-tools         conda-forge/linux-64::glib-tools-2.84.3-hf516916_0
#   graph-tool         conda-forge/linux-64::graph-tool-2.98-py311h2cebea5_400
#   graph-tool-base    conda-forge/linux-64::graph-tool-base-2.98-py311h78e300f_400
#   gtk3               conda-forge/linux-64::gtk3-3.24.43-h021d004_3
#   hicolor-icon-theme conda-forge/linux-64::hicolor-icon-theme-0.17-ha770c72_2
#   libboost           conda-forge/linux-64::libboost-1.86.0-hed09d94_4
#   libboost-python    conda-forge/linux-64::libboost-python-1.86.0-py311h1d5f577_4
#   libcups            conda-forge/linux-64::libcups-2.3.3-hb8b1518_5
#   libdrm             conda-forge/linux-64::libdrm-2.4.125-hb03c661_1
#   libegl             conda-forge/linux-64::libegl-1.7.0-ha4b6fd6_2
#   libegl-devel       conda-forge/linux-64::libegl-devel-1.7.0-ha4b6fd6_2
#   libfreetype        conda-forge/linux-64::libfreetype-2.14.1-ha770c72_0
#   libfreetype6       conda-forge/linux-64::libfreetype6-2.14.1-h73754d4_0
#   libgcc             conda-forge/linux-64::libgcc-15.2.0-h767d61c_7
#   libgfortran        conda-forge/linux-64::libgfortran-15.2.0-h69a702a_7
#   libgirepository    conda-forge/linux-64::libgirepository-1.84.0-h61e2d6e_2
#   libgl              conda-forge/linux-64::libgl-1.7.0-ha4b6fd6_2
#   libgl-devel        conda-forge/linux-64::libgl-devel-1.7.0-ha4b6fd6_2
#   libglvnd           conda-forge/linux-64::libglvnd-1.7.0-ha4b6fd6_2
#   libglx             conda-forge/linux-64::libglx-1.7.0-ha4b6fd6_2
#   libglx-devel       conda-forge/linux-64::libglx-devel-1.7.0-ha4b6fd6_2
#   liblzma            conda-forge/linux-64::liblzma-5.8.1-hb9d3cd8_2
#   liblzma-devel      conda-forge/linux-64::liblzma-devel-5.8.1-hb9d3cd8_2
#   libpciaccess       conda-forge/linux-64::libpciaccess-0.18-hb9d3cd8_0
#   librsvg            conda-forge/linux-64::librsvg-2.58.4-he92a37e_3
#   libstdcxx          conda-forge/linux-64::libstdcxx-15.2.0-h8f9b012_7
#   libxkbcommon       conda-forge/linux-64::libxkbcommon-1.7.0-h2c5496b_1
#   pycairo            conda-forge/linux-64::pycairo-1.28.0-py311hc1a9592_1
#   pygobject          conda-forge/linux-64::pygobject-3.50.0-py311hba7ce5e_1
#   sigcpp-3.0         conda-forge/linux-64::sigcpp-3.0-3.6.0-h59595ed_0
#   sparsehash         conda-forge/linux-64::sparsehash-2.0.4-hcb278e6_1
#   wayland            conda-forge/linux-64::wayland-1.24.0-h3e06ad9_0
#   xkeyboard-config   conda-forge/linux-64::xkeyboard-config-2.46-hb03c661_0
#   xorg-libxcomposite conda-forge/linux-64::xorg-libxcomposite-0.4.6-hb9d3cd8_2
#   xorg-libxcursor    conda-forge/linux-64::xorg-libxcursor-1.2.3-hb9d3cd8_0
#   xorg-libxdamage    conda-forge/linux-64::xorg-libxdamage-1.1.6-hb9d3cd8_0
#   xorg-libxfixes     conda-forge/linux-64::xorg-libxfixes-6.0.2-hb03c661_0
#   xorg-libxi         conda-forge/linux-64::xorg-libxi-1.8.2-hb9d3cd8_0
#   xorg-libxinerama   conda-forge/linux-64::xorg-libxinerama-1.1.5-h5888daf_1
#   xorg-libxrandr     conda-forge/linux-64::xorg-libxrandr-1.5.4-hb9d3cd8_0
#   xorg-libxtst       conda-forge/linux-64::xorg-libxtst-1.2.5-hb9d3cd8_3
#   xorg-libxxf86vm    conda-forge/linux-64::xorg-libxxf86vm-1.1.6-hb9d3cd8_0
#   xorg-xorgproto     conda-forge/linux-64::xorg-xorgproto-2024.1-hb9d3cd8_1
#   xz-gpl-tools       conda-forge/linux-64::xz-gpl-tools-5.8.1-hbcc6ac9_2
#   xz-tools           conda-forge/linux-64::xz-tools-5.8.1-hb9d3cd8_2
#
# The following packages will be UPDATED:
#
#   blas                                       2.122-openblas --> 2.136-openblas
#   blas-devel                      3.9.0-22_linux64_openblas --> 3.9.0-36_h1ea3ea9_openblas
#   c-ares                                  1.28.1-hd590300_0 --> 1.34.5-hb9d3cd8_0
#   c-blosc2                                2.15.0-h6d6b9e4_1 --> 2.15.2-h68e2383_0
#   ca-certificates    conda-forge/linux-64::ca-certificates~ --> conda-forge/noarch::ca-certificates-2025.10.5-hbd8a1cb_0
#   cairo                                   1.18.0-hbb29018_2 --> 1.18.4-h3394656_0
#   certifi                             2024.6.2-pyhd8ed1ab_0 --> 2025.10.5-pyhd8ed1ab_0
#   curl                                     8.8.0-he654da7_1 --> 8.14.1-h332b0f4_0
#   expat                                    2.6.2-h59595ed_0 --> 2.7.1-hecca717_0
#   fontconfig                              2.14.2-h14ed4e7_0 --> 2.15.0-h7e30c49_1
#   freetype                                2.12.1-h267a509_2 --> 2.14.1-ha770c72_0
#   harfbuzz                                 8.5.0-hfac3d4d_0 --> 11.3.3-hbb57e21_0
#   icu                                       73.2-h59595ed_0 --> 75.1-he02047a_0
#   imagecodecs                      2024.6.1-py311hb8791aa_2 --> 2024.6.1-py311h732c098_3
#   lcms2                                     2.16-hb7c19ff_0 --> 2.17-h717163a_0
#   libavif16                                1.0.4-hd2f8ffe_4 --> 1.2.1-hbb36593_2
#   libblas                         3.9.0-22_linux64_openblas --> 3.9.0-36_h4a7cf45_openblas
#   libcblas                        3.9.0-22_linux64_openblas --> 3.9.0-36_h0358290_openblas
#   libcurl                                  8.8.0-hca28451_1 --> 8.14.1-h332b0f4_0
#   libdeflate                                1.20-hd590300_0 --> 1.21-h4bc722e_0
#   libexpat                                 2.6.2-h59595ed_0 --> 2.7.1-hecca717_0
#   libffi                                   3.4.2-h7f98852_5 --> 3.4.6-h2dba641_1
#   libgcc-ng                               14.1.0-h77fa898_0 --> 15.2.0-h69a702a_7
#   libgfortran-ng                          14.1.0-h69a702a_0 --> 15.2.0-h69a702a_7
#   libgfortran5                            14.1.0-hc5f4f2c_0 --> 15.2.0-hcd61629_7
#   libgit2                                  1.8.1-he8d1d4c_1 --> 1.9.1-h014eb84_0
#   libglib                                 2.80.2-h8a4344b_1 --> 2.84.3-hf39c6af_0
#   libgomp                                 14.1.0-h77fa898_0 --> 15.2.0-h767d61c_7
#   libiconv                                  1.17-hd590300_2 --> 1.18-h3b78370_2
#   libjpeg-turbo                            3.0.0-hd590300_1 --> 3.1.0-hb9d3cd8_0
#   liblapack                       3.9.0-22_linux64_openblas --> 3.9.0-36_h47877c9_openblas
#   liblapacke                      3.9.0-22_linux64_openblas --> 3.9.0-36_h6ae95b6_openblas
#   libnghttp2                              1.58.0-h47da74e_1 --> 1.67.0-had1ee68_0
#   libopenblas                    0.3.27-pthreads_h413a1c8_0 --> 0.3.30-pthreads_h94d23a6_2
#   libpng                                  1.6.43-h2797004_0 --> 1.6.50-h421ea60_1
#   libssh2                                 1.11.0-h0841786_0 --> 1.11.1-hcf80075_0
#   libstdcxx-ng                            14.1.0-hc0a3c3a_0 --> 15.2.0-h4852527_7
#   libtiff                                  4.6.0-h1dd3fc0_3 --> 4.7.0-h6565414_0
#   libxcb                                    1.16-hd590300_0 --> 1.17.0-h8a09558_0
#   libxml2                                 2.12.7-hc051c1a_1 --> 2.13.8-h04c0eec_1
#   nodejs                                 20.12.2-hb753e55_0 --> 20.17.0-hc55a1b2_0
#   openblas                       0.3.27-pthreads_h7a3da1a_0 --> 0.3.30-pthreads_h6ec200e_2
#   openjpeg                                 2.5.2-h488ebb8_0 --> 2.5.3-h55fea9a_1
#   openssl                                  3.3.1-h4ab18f5_1 --> 3.5.4-h26f9b46_0
#   pango                                   1.54.0-h84a9a3c_0 --> 1.56.4-hadf4263_0
#   pcre2                                    10.44-h0f59acf_0 --> 10.45-hc749103_0
#   pillow                             10.4.0-py311h82a398c_0 --> 11.0.0-py311h49e9ac3_0
#   pixman                                  0.43.2-h59595ed_0 --> 0.46.4-h54a6638_1
#   r-base                                   4.3.3-he2d9a6e_8 --> 4.3.3-h65010dc_18
#   r-gert                                2.0.1-r43h9b95477_1 --> 2.1.5-r43h5e22a44_0
#   r-ragg                                1.3.2-r43hffa04bc_0 --> 1.5.0-r43h9f1dc4d_0
#   r-stringi                             1.8.4-r43hbd1cc82_1 --> 1.8.7-r43h3c328a7_0
#   r-textshaping                         0.4.0-r43h024d615_0 --> 1.0.1-r43h16f7c1a_0
#   snappy                                   1.2.0-hdb0a2a9_1 --> 1.2.2-h03e3b7b_0
#   svt-av1                                  2.1.0-hac33072_0 --> 3.0.2-h5888daf_0
#   xorg-libice                              1.1.1-hd590300_0 --> 1.1.2-hb9d3cd8_0
#   xorg-libsm                               1.2.4-h7391055_0 --> 1.2.6-he73a12e_0
#   xorg-libx11                              1.8.9-hb711507_1 --> 1.8.12-h4f16b4b_0
#   xorg-libxext                             1.3.4-h0b41bf4_2 --> 1.3.6-hb9d3cd8_0
#   xorg-libxrender                         0.9.11-hd590300_0 --> 0.9.12-hb9d3cd8_0
#   xz                                       5.2.6-h166bdaf_0 --> 5.8.1-hbcc6ac9_2
#   zlib-ng                                  2.2.0-hac33072_0 --> 2.2.5-hde8ca8f_0
#   zstandard                          0.22.0-py311hb6f056b_1 --> 0.25.0-py311haee01d2_0
#   zstd                                     1.5.6-ha6fb4c9_0 --> 1.5.7-hb8e6e7a_2
#
#
#
# Downloading and Extracting Packages:
# graph-tool-base-2.98 | 58.9 MB   |                                       |   0%
# pillow-11.0.0        | 40.5 MB   |                                       |   0%
#
# r-base-4.3.3         | 24.5 MB   |                                       |   0%
#
#
# nodejs-20.17.0       | 16.4 MB   |                                       |   0%
#
#
#
# icu-75.1             | 11.6 MB   |                                       |   0%
#
#
#
#
# librsvg-2.58.4       | 6.2 MB    |                                       |   0%
#
#
#
#
#
# openblas-0.3.30      | 5.8 MB    |                                       |   0%
#
#
#
#
#
#
# libopenblas-0.3.30   | 5.7 MB    |                                       |   0%
#
#
#
#
#
#
#
# gtk3-3.24.43         | 5.3 MB    |                                       |   0%
#
#
#
#
#
#
#
#
# libcups-2.3.3        | 4.3 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# libglib-2.84.3       | 3.8 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# libstdcxx-15.2.0     | 3.7 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.5.4        | 3.0 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.86.0      | 2.8 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# svt-av1-3.0.2        | 2.6 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# imagecodecs-2024.6.1 | 2.0 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-11.3.3      | 1.7 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran5-15.2.0  | 1.5 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pcre2-10.45          | 1.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgit2-1.9.1        | 1007 KB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.4         | 955 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# r-stringi-1.8.7      | 884 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libx11-1.8.12   | 816 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# pillow-11.0.0        | 40.5 MB   |                                       |   0%
#
# r-base-4.3.3         | 24.5 MB   |                                       |   0%
#
#
# nodejs-20.17.0       | 16.4 MB   |                                       |   0%
#
#
#
# graph-tool-base-2.98 | 58.9 MB   |                                       |   0%
#
#
# nodejs-20.17.0       | 16.4 MB   | ####3                                 |  12%
#
# r-base-4.3.3         | 24.5 MB   | ##5                                   |   7%
# pillow-11.0.0        | 40.5 MB   | #2                                    |   3%
#
#
#
# graph-tool-base-2.98 | 58.9 MB   | 9                                     |   3%
#
# r-base-4.3.3         | 24.5 MB   | ########7                             |  24%
# pillow-11.0.0        | 40.5 MB   | ###5                                  |   9%
#
#
#
# icu-75.1             | 11.6 MB   | ####################7                 |  56%
#
#
# graph-tool-base-2.98 | 58.9 MB   | ###3                                  |   9%
#
# r-base-4.3.3         | 24.5 MB   | ################                      |  43%
# pillow-11.0.0        | 40.5 MB   | #####4                                |  15%
#
#
# nodejs-20.17.0       | 16.4 MB   | ################8                     |  45%
#
#
#
# graph-tool-base-2.98 | 58.9 MB   | ######8                               |  18%
#
# r-base-4.3.3         | 24.5 MB   | #####################                 |  57%
# pillow-11.0.0        | 40.5 MB   | ########1                             |  22%
#
#
# nodejs-20.17.0       | 16.4 MB   | ##########################5           |  72%
#
# r-base-4.3.3         | 24.5 MB   | ##########################7           |  72%
#
#
#
#
# librsvg-2.58.4       | 6.2 MB    |                                       |   0%
# pillow-11.0.0        | 40.5 MB   | #########9                            |  27%
#
#
# graph-tool-base-2.98 | 58.9 MB   | #########                             |  24%
#
# r-base-4.3.3         | 24.5 MB   | ###############################8      |  86%
#
#
#
#
# librsvg-2.58.4       | 6.2 MB    | #################4                    |  47%
# graph-tool-base-2.98 | 58.9 MB   | ##########8                           |  29%
# graph-tool-base-2.98 | 58.9 MB   | ############9                         |  35%
#
#
#
#
#
# graph-tool-base-2.98 | 58.9 MB   | ##############7                       |  40%
# pillow-11.0.0        | 40.5 MB   | ###############2                      |  41%
#
#
#
#
#
#
# libopenblas-0.3.30   | 5.7 MB    | 1                                     |   0%
#
#
#
#
#
# graph-tool-base-2.98 | 58.9 MB   | #################3                    |  47%
# pillow-11.0.0        | 40.5 MB   | #################                     |  46%
#
#
#
#
#
#
# libopenblas-0.3.30   | 5.7 MB    | ##########6                           |  29%
# graph-tool-base-2.98 | 58.9 MB   | ###################3                  |  52%
#
#
#
#
#
#
# libopenblas-0.3.30   | 5.7 MB    | #################7                    |  48%
#
#
#
#
#
#
#
# gtk3-3.24.43         | 5.3 MB    | 1                                     |   0%
#
#
#
# icu-75.1             | 11.6 MB   | ##################################### | 100%
# pillow-11.0.0        | 40.5 MB   | ####################2                 |  55%
#
#
#
#
#
#
# graph-tool-base-2.98 | 58.9 MB   | #####################3                |  58%
#
#
#
#
#
#
#
#
# libcups-2.3.3        | 4.3 MB    | 1                                     |   0%
#
#
#
#
#
#
#
# graph-tool-base-2.98 | 58.9 MB   | #######################1              |  63%
#
#
#
#
#
#
#
#
# libcups-2.3.3        | 4.3 MB    | #########################1            |  68%
#
#
#
#
# librsvg-2.58.4       | 6.2 MB    | ##################################### | 100%
#
#
#
#
# librsvg-2.58.4       | 6.2 MB    | ##################################### | 100%
# graph-tool-base-2.98 | 58.9 MB   | #########################8            |  70%
# graph-tool-base-2.98 | 58.9 MB   | ############################8         |  78%
#
#
#
#
#
#
#
#
#
#
# libstdcxx-15.2.0     | 3.7 MB    | 1                                     |   0%
# graph-tool-base-2.98 | 58.9 MB   | ################################2     |  87%
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.5.4        | 3.0 MB    | 1                                     |   1%
# graph-tool-base-2.98 | 58.9 MB   | ###################################   |  95%
#
#
#
#
#
#
#
#
#
# libglib-2.84.3       | 3.8 MB    | 1                                     |   0%
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.5.4        | 3.0 MB    | ########################8             |  67%
# pillow-11.0.0        | 40.5 MB   | ##############################7       |  83%
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.86.0      | 2.8 MB    | 2                                     |   1%
# pillow-11.0.0        | 40.5 MB   | ##################################    |  92%
#
#
#
#
#
#
#
#
#
# libglib-2.84.3       | 3.8 MB    | ####################1                 |  55%
#
#
#
#
#
#
#
#
#
#
#
#
#
# svt-av1-3.0.2        | 2.6 MB    | 2                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.86.0      | 2.8 MB    | ################################3     |  87%
# pillow-11.0.0        | 40.5 MB   | ####################################4 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# imagecodecs-2024.6.1 | 2.0 MB    | 2                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran5-15.2.0  | 1.5 MB    | 3                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-11.3.3      | 1.7 MB    | 3                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pcre2-10.45          | 1.1 MB    | 5                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgit2-1.9.1        | 1007 KB   | 5                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libx11-1.8.12   | 816 KB    | 7                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.4         | 955 KB    | 6                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# r-stringi-1.8.7      | 884 KB    | 6                                     |   2%
#
#
#
#
#
# openblas-0.3.30      | 5.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# r-base-4.3.3         | 24.5 MB   | ##################################### | 100%
#
# r-base-4.3.3         | 24.5 MB   | ##################################### | 100%
#
#
#
#
#
#
# libopenblas-0.3.30   | 5.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
# gtk3-3.24.43         | 5.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# libcups-2.3.3        | 4.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# libstdcxx-15.2.0     | 3.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# libstdcxx-15.2.0     | 3.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.5.4        | 3.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# libglib-2.84.3       | 3.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# libglib-2.84.3       | 3.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.86.0      | 2.8 MB    | ##################################### | 100%
#
#
# nodejs-20.17.0       | 16.4 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# svt-av1-3.0.2        | 2.6 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# svt-av1-3.0.2        | 2.6 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran5-15.2.0  | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran5-15.2.0  | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-11.3.3      | 1.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-11.3.3      | 1.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# imagecodecs-2024.6.1 | 2.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# imagecodecs-2024.6.1 | 2.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgit2-1.9.1        | 1007 KB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgit2-1.9.1        | 1007 KB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# r-stringi-1.8.7      | 884 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# r-stringi-1.8.7      | 884 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.4         | 955 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.4         | 955 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libx11-1.8.12   | 816 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libx11-1.8.12   | 816 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pcre2-10.45          | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pcre2-10.45          | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# graph-tool-base-2.98 | 58.9 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: /
# /
# /
# done

# %%
from graph_tool.all import *

# %% [markdown]
# And creating a graph is simple, we just ask for a graph.

# %%
g = Graph()
g
# Out:
# <Graph object, directed, with 0 vertices and 0 edges, at 0x7f4ba90e0a10>

# %% [markdown]
# By default `Graph()` will create an empty directed graph object. If we want to add our nodes, we do that by asking it to add a vertex

# %%
v1 = g.add_vertex()
v2 = g.add_vertex()
v2
# Out:
# <Vertex object with index '1' at 0x7f4ba76fe5c0>

# %%
[x for x in g.vertices()]
# Out:
# [<Vertex object with index '0' at 0x7f4ba76fedc0>,
#  <Vertex object with index '1' at 0x7f4ba76feb40>]

# %% [markdown]
# You can see that the added vertices are given an index and added to the graph.

# %%
graph_draw(g, vertex_text=g.vertex_index)
# Out:
# <VertexPropertyMap object with value type 'vector<double>', for Graph 0x7f4ba90e0a10, at 0x7f5012bb3810>

# %% [markdown]
# And if we draw the graph, we can see that it's all there but basic -- two simple disconnected vertices. We need to add the edges between vertices in order to actually connect it.

# %%
e1 = g.add_edge(v1, v2)
graph_draw(g, vertex_text=g.vertex_index)
# Out:
# <VertexPropertyMap object with value type 'vector<double>', for Graph 0x7f4ba90e0a10, at 0x7f4ba7652cd0>

# %% [markdown]
# Now we see the connection between vertex `0` and `1`, with an edge (arrow) pointing from vertex `0` to vertex `1`.
#
# This pointed arrow denotes **directionality**, it says that information is passed from `v1`  to `v2`, but not vice-versa. If you wanted this relationship to be bi-directional, you would need to add a second edge that says that the **source** of the connection is `v2` and the **target** of that information is `v1`.

# %%
e1 = g.add_edge(v2, v1)
graph_draw(g, vertex_text=g.vertex_index)
# Out:
# <VertexPropertyMap object with value type 'vector<double>', for Graph 0x7f4ba90e0a10, at 0x7f4ba8142990>

# %% [markdown]
# and now we see two edges, with one originating from each one of the nodes and this will denote that `v1` sends to `v2` and vice versa.
#
# ## Question
#
# * What are the potential types of connections/transactions where it should be bidirectional?
# * Simply directional?
# * Does direction always matter?

# %% [markdown]
# # Theoretical graphs and construction
#
# ## Undirected vs. Directed
#
# An **undirected** network means that an edge has no direction, in our network an edge means that an edge goes for both of the nodes.
#
# If we wanted to examine a network where we looked at who initiated a conversation with whom during a day, we would want a **directed** network. **By default** graph-tool constructs a directed network.
#
# <img src="https://blogs.sas.com/content/graphicallyspeaking/files/2016/05/Network_Icon_Single__15_B.png" width="400px"></img>
#
# In a directed network an edge is displayed with an arrow and it shows the direction of the edge and it is not symmetric, **unlike** an undirected network. This means that if:
# * Bob starts a conversation with Alice, then we would draw an edge from Bob to Alice with the arrow pointed to Alice
# * Later that day Alice started a conversation with Bob, we would draw another edge from Alice to Bob, with the arrow pointed at Bob
#
# If we want an undirected network, we can specify that at the time of graph creation

# %%
ug = Graph(directed=False)
uv0 = ug.add_vertex()
uv1 = ug.add_vertex()
ue0 = ug.add_edge(uv0, uv1)
graph_draw(ug, vertex_text=ug.vertex_index)

# %% [markdown]
# ## Unweighted vs. Weighted
#
# An **unweighted** network has edges that are effectively binary, either there exists an edge between two nodes or there does not exist an edge. All edges that exist are counted the same.  This type of network makes sense for friendship, since two people are either friends or they are not.
#
# If we think about our conversation network though, we would want to know the **number** of times that two individuals interact --- especially because it is likely that all of the individuals would talk to each other during the course of a day. This means that the presence or absence of an edge doesn't matter because it is a **fully connected** network. We would add the **number** of conversations, more typically known as the **weight** of an edge, to represent the strength of the connection between two nodes. In a graph we typically show weights by making the width of an edge larger.
# <img src="https://humannaturegroup.files.wordpress.com/2009/12/map.png" width="400px"></img>

# %%
ug = Graph(directed=False)
# Create the edge weight property
eweight = ug.new_ep('double')
# g.edge_properties['weight'] = edge_weights
ug.add_edge_list([(0, 1, 2), (1, 2, 10)], eprops=[eweight])
#Draw the graph
graph_draw(ug, vertex_text=ug.vertex_index, edge_pen_width=eweight)
eweight.fa

# %% [markdown]
# # Summing up the basics
#
# So far we have covered creating a graph, creating a few nodes and edges, and graphing it (which actually looks rather nice!). There's a little bit of work we have to do to have properties for edges and vertices (with the definition of the data type in C++ data struct language), but that's all in the name of speed.
#
# For reinforcement let's create a simple communication network for four co-workers.

# %%
import itertools
#Our four individuals
individuals = ['Alice', 'Bob', 'Carol', 'David']
edge_list = [x for x in itertools.combinations(individuals, 2)]

G = Graph()
#Add the edges, hashed tells graph-tool to infer the index numbers
vmap = G.add_edge_list(edge_list, hashed=True)
graph_draw(G, vertex_text=vmap)

# %% [markdown]
# We can remove a node if need be from the graph

# %%
G.remove_vertex(0)
graph_draw(G, vertex_text = vmap)

# %% [markdown]
# And check all our nodes now:

# %%
[x for x in G.vertices()]

# %% [markdown]
# Importantly all of our vertices are numbers not names -- why? **Discussion** of old times
#
# But with a vertex we can perform many operations to extract data from the graph.

# %%
tv = [x for x in G.vertices()][0]
#Get edges:
print('edges for vertex 0')
for x in tv.all_edges():
    print(x)
print('--')
#Or get all neighbors
print('neighbors for vertex 0')
for x in tv.all_neighbors():
    print(x)
print('--')
#Or just count neighbors
print(f'vertex 0 has {tv.in_degree() + tv.out_degree()} neighbors')
#Weren't expecting that were you??

# %% [markdown]
# Of course we don't have to iterate through this manner to access these attributes

# %%
print(f'Vertex 1 has in-degree {G.vertex(1).in_degree()} and out-degree {G.vertex(1).out_degree()}')

# %% [markdown]
# # Basic network statistics
#
# **Degree** - the number of connections you have to other vertices. In-degree is the number of incoming links and out-degree is the number of outgoing links. Total degree is the sum of these two, in an unweighted network total degree is equal to the number of network neighbors.
#
# **Centrality** - whoo, well there's a number of these. Effectively a measure of how 'central' a vertex is in the network. There are many mathematical formulations which are different interpretations of what the word 'central' means. Requires the entire context of the network to calculate.
#
# **Clustering** - How tightly closed the connections are in your local sphere, i.e. are your friends friends?

# %%
#Reset the network
G = Graph(directed=False)
#Add the edges, hashed tells graph-tool to infer the index numbers
vmap = G.add_edge_list(edge_list, hashed=True)

# %%
#calculate betweenness centrality
bet_vmap, bet_emap = betweenness(G)
bet_vmap[3]

# %%
#Calculate clustering coefficient
clust_vmap = local_clustering(G)
clust_vmap[2]

# %% [markdown]
# Really boring because the network isn't bit enough!
#
# So let's step up our game here and transition to a larger network. For this we'll use the divvy bikes network that's in the data folder.
#
# # Divvy network
#
# The `divvy_network.json` has the divvy stations as vertices and the edges are a bike being checked out at one station and docked at another.
#
# `graph-tool` doesn't support json as a network format though, so we'll need to do a transformation using NetworkX.

# %%
import networkx as nx
from networkx.readwrite import json_graph
import json

data = json.load(open('../data/divvy_network.json'))
G = json_graph.node_link_graph(data)
#Need to sanitize out all the information
H = nx.Graph()
H.add_edges_from(G.edges())
#And graph_tool can read graph_ml
nx.readwrite.write_gml(H, '../data/divvy_network.gml')

# %% [markdown]
# If we write out a graph in the gml format (which requires stripping properties), then we can read it in.

# %%
# !head ../data/divvy_network.gml

# %%
divvyg = load_graph('../data/divvy_network.gml')
graph_draw(divvyg)

# %% [markdown]
# Pretty!
#
# Understanding non-trivial networks is difficult by plotting the network because of the large number of nodes and edges that would overlap. For this reason we typically look at distributions of network statistics, such as the distribution of degrees.

# %%
#Exercise
# Plotting the distribution of degrees

# %% [markdown]
# So what we can see is that there is a slight peak near the larger side of the distribution, this means that there are a number of Divvy stations that see a large number of trips.
#
# Since the Divvy Trip network is a transportation network (it shows movement from one station to another) we can look at betweenness centrality. Betweenness centrality for a node `i` is the sum of the fraction of shortest paths that pass through `i`.

# %%
# Exercise
# Distribution of betweenness centrality

# %% [markdown]
# Now we should look and see if this network is assortative. That means, what is my degree versus my neighbor's degree? Am I typically connected to neighbors that have the same degree as me or not?

# %%
#Exercise

# %% [markdown]
# The network is assortative, nodes with a high-degree have neighbors that also have a high degree.
#
# ### Why is that? When would the converse be true?

# %% [markdown]
# We can and should check this though. Implement a function to calculate the distance between two stations with the [Haversine distance](https://en.wikipedia.org/wiki/Haversine_formula)

# %%
#Exercise

# %% [markdown]
# Interesting, this appears to be a pretty small distance. But to make sure we should calculate and plot the differences between distance between neighbors and distance between non-neighbors

# %%
#Exercise

# %%
ax = plt.subplot(111)
ax.boxplot([avg_neighbor_distances, avg_non_neighbor_distances])
plt.setp(ax, xticklabels=['Neighbor', 'Non-Neighbor'])
ax.set_xlim(0.5,2.5)
ax.set_ylabel('Distance')
plt.tight_layout()

# %% [markdown]
# Now let's test whether these two distributions from the same distribution or not, using the Kolmogorov-Smirnov test.
#
# **Are these two distributions the same or not?**

# %%
from scipy.stats import ks_2samp

D, p = ks_2samp(avg_neighbor_distances, avg_non_neighbor_distances)
print( p )

# %% [markdown]
# # Network Path Traversal
#
# Another important part is traversing a network. What are two easy ways that this could be done?
#
# **answer is....**
#
# Breadth-first or depth-first
#
# Perfect!
#
# Now let's implement breadth first of these algorithms
#
# so if we have a tree like:
#
# `
#  -> My tree starting from Z
#      Z
#   |     |
#   B     C
# |  |  |  |
# D  E  F  G
# `
#
# The answer should be:
# [B, C, D, E, F, G]

# %%
#Exercise

# %% [markdown]
# But there's a simpler way to do this, since it's a built in method of networkx
