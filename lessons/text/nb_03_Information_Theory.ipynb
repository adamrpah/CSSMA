# %% [markdown]
# # What is information theory and why am I wasting your time?
#
# Information theory is about the quantification, storage, and communication of information. It started in the late 1940s when Claude Shannon prposed it in his paper entitled "A mathematical theory of communication".
#
# So **why** do I bring this up?

# %% [markdown]
# **text is inherently about communication**

# %% [markdown]
# # The concept of information theory
#
# The most basic part of information theory that you all will have experienced is the concept of encoding. If you've ever played an MP3 or opened a zip file you've dealt with this.
#
# The idea of encoding is to compress information without losing fidelity. As an overly simple example, consider the string:
#
# `00001111`
#
# which has 8 characters. If we were to introduce a translation table that said `0` means `0000` and `1` means `1111` then we could reduce that string to:
#
# `01`
#
# without losing any information. This is one, extremely basic, aspect of information theory, but it demonstrates the larger principle: how can we quantify the amount of information in some quantity and 'transport' it.

# %% [markdown]
# # Entropy
#
# Entropy is one of the foundational calculations in Information Theory and it is effectively similar to the entropy calculation in thermodynamics. In information theory, we use entropy in the form of:
#
# $H(X)=-\sum_{i=1}^{n}p_i log(p_i)$
#
# which is for a discrete variable. The probability of $i$ ($p_i$) depends on the distribution of $X$.

# %% [markdown]
# We can then code a function to calculate entropy given a list of words.

# %%
sample_data_1 = ['i', 'i', 'i', 'am', 'am', 'are']
sample_data_2 = ['hello', 'how', 'are', 'you', 'doing', 'today']
sample_data_3 = ['i', 'i', 'i', 'i', 'i', 'i']

# %%
#Exercise

# %% [markdown]
# The value of entropy increases as the system's disorder grows, which means that more unique words are used in the context of text.
#
# We can also use the entropy implementation in scipy stats, which removes the need to write it ourselves (we do however, have to transform the word list to counts).

# %%
#Exercise - Scipy implementaiton

# %% [markdown]
# Compare the entropy of the speaking parts for the characters in Othello

# %%
#Exercise

# %% [markdown]
# And now we can see an issue - Othello has a larger lexical diversity but a smaller entropy.
#
# Lexical diversity is a rather simplistic measure - and as such it will be more sensitive to mild differences in the number of unique words as the size of the total vocabulary decreases. These differences are not likely to be statistically significant, but they can give the appearance of a larger difference than truly exists.
#
# In this example, lexical diversity would suggest that the difference in vocabulary complexity is twice as much as with entropy (when we already know that this difference is not significant from our test in the previous notebook).

# %% [markdown]
# # Surprise!
#
# The other concept that I want to talk about is the Kullback-Leibler (KL) divergence. The KL divergence is a measure of relative entropy, so how much entropy there is in dataset $P$ given knowledge of $Q$. Its output is continuous from 0 to 1, and when $D_{KL}=1$ one would never expect to see $P$ after having learned from $Q$. This range of outputs and its meaning is why the KL divergence can be simplified to an explanation of one's 'surprise' at seeing a dataset.
#
# The KL divergence is implemented as:
#
# $D_{KL}(P||Q)=-\sum_i P(i)log\frac{Q(i)}{P(i)}$
#
# where each $i$ is a discrete support.

# %% [markdown]
# # The value of "surprise"
#
# We can do a basic, but not very meaningful, example that compares othello's text given iago's. Implement the KL divergence function and calculate it.

# %%
#Exercise

# %% [markdown]
# And of course, we could just use the scipy function to calculate this (but it wouldn't be as obvious as to why we have to restrict the input to shared words only).

# %%
stats.entropy(othello_support, qk = iago_support)

# %% [markdown]
# # Practical applications of KL divergence.
#
# KL divergence has a very straightforward interpretation as surprise and it is bounded from 0 to 1 (making its interpretation intuitive).
#
# The value in this metric is it provides a way to quantify the amount of change from one document to the next (or one type of document to the next). It provides an easy, grounded way to assess the change in a document over time (think financial reports from quarter to quarter) or between documents that one thinks should be similar.

# %% [markdown]
# # Mutual Information
#
# With those definitions, it's now not as much of a stretch to understand mutual information
#
# $I(X;Y)=H(X)-H(X|Y)$
#
# but could also be written as
#
# $I(X;Y)=\sum_{i=1}^n\sum_{j=1}^m p_{ij} log\frac{p_{ij}}{p_{i}p_{j}}$
#
# so the difference in one distributions' entropy minus the amount of entropy that is conditional on a second distribution.

# %%
#Exercise

# %% [markdown]
# # Back to basics
#
# So now we have these metrics which are grounded in information theory and we could draw comparisons to earlier descriptive statistics that we used in the second week.
#
# For example, we could compare the lexical divergence (# of unique words/total words) to the entropy for each characters dialogue.
#
# Let's calculate and compare the two values by plotting them as a scatterplot.

# %%
#Exercise

# %% [markdown]
# # Statistical testing
#
# Whenever we generate quantitative insights we can begin to ask the question "Does this significantly differ?"
#
# However, one of the issues we commonly face is that our most standard statistical test (t-test) relies on an assumption that the data is normally distributed. If we wanted to ask if the difference in entropy between two characters is significant that isn't something that we can text with the student's t distribution (or really any other classical test).
#
# All of these statistical test though really do one thing -- compare a value to a known distribution to determine if it differs significantly.
#
# Instead of using a canned statistical test, we can actually simulate our own null distribution and use that to determine if the observed value significantly differs.
#
# ## Bootstrapping
#
# How we simulate our own null distribution is through [bootstrapping](https://en.wikipedia.org/wiki/Bootstrapping_(statistics)). In bootstrapping we estimate the distribution of an estimator by resampling the data and calculating the estimator as shown here:
#
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/4/4a/Illustration_bootstrap.svg/960px-Illustration_bootstrap.svg.png)

# %% [markdown]
# Now as an example let's revisit Dr. Seuss' *The Butter Battle Book* with the Yooks and the Zooks. The Yooks butter their bread with the butter side up and the Zooks butter their bread with the butter side down.
#
# ![](https://m.media-amazon.com/images/M/MV5BMTExMWIwNWEtOGFhNi00MjI1LThlYmItY2QwYTM1NmFiZDliXkEyXkFqcGc@._V1_.jpg)
#
# To quantitatively assess if there is any difference in the snack between the groups you surveyed 30 individuals from both the Yooks and the Zooks and weighed the grams of butter on the piece of bread.
#
# Below is your data:

# %%
yooks = [ 6.04659908, 12.4310568 , 13.65645246,  9.18941801, 11.11538492,
       12.83193796, 12.89295398,  4.29587094, 10.46681029, 10.08530845,
        6.12919313, 12.72233935,  9.92375271,  9.27175324,  8.50807749,
       11.35013295,  8.64545843,  7.01734624, 16.42865828,  4.89110198,
       12.11397248,  3.85572612,  9.33218949,  8.39478144, 11.85653964,
       11.08352718,  4.27128407,  9.17940528, 10.20145033,  9.15335866]
zooks = [ 8.35046241, 11.77684031, 11.81356971,  9.5946012 , 11.76530252,
       13.60142142,  7.4875778 , 11.07370866, 13.99039017,  8.89156716,
        8.57843413,  7.68743201,  8.7368102 , 10.6587579 , 17.81259339,
       10.24552581, 10.7345202 , 10.77512685, 11.63143453,  7.46793981,
        3.11953331,  6.01087168, 12.20931055,  8.22888629, 10.34684699,
        8.36772757,  6.91561127,  8.54928903, 11.93326687, 10.48545184]
# Out:
# [8.35046241,
#  11.77684031,
#  11.81356971,
#  9.5946012,
#  11.76530252,
#  13.60142142,
#  7.4875778,
#  11.07370866,
#  13.99039017,
#  8.89156716,
#  8.57843413,
#  7.68743201,
#  8.7368102,
#  10.6587579,
#  17.81259339,
#  10.24552581,
#  10.7345202,
#  10.77512685,
#  11.63143453,
#  7.46793981,
#  3.11953331,
#  6.01087168,
#  12.20931055,
#  8.22888629,
#  10.34684699,
#  8.36772757,
#  6.91561127,
#  8.54928903,
#  11.93326687,
#  10.48545184]

# %% [markdown]
# How would you classically test if these two groups were different?

# %% [markdown]
# Now how would you bootstrap a test to determine if the observed mean is different than the mean difference that we would expect by random chance?

# %% [markdown]
# ## Back to character words
#
# Now how could we do this to determine if the difference in entropy between any two characters is significantly different? i.e. what do we need to hold constant in our sampling procedure so that this is a fair comparison?

# %%
#Exercise -- implement the bootstrap of the difference in Entropy between two characters
