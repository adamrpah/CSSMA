# %% [markdown]
# # NLTK
#
# Last week we started with implementing core concepts on our own. This week we will explore the resources that are available for us to make this -- specifically we will talk about constructing our data pipeline with NLTK methods.

# %% [markdown]
# ## Data processing pipeline for text
#
# When dealing with a text, we are generically going to follow constructing a pipeline of:
#
# Text -> `preprocessing` -> tokens -> `feature extraction` -> numerical data
#
# For more detail on what each of those steps entail, we can reference this flowchart:
#
# ![Diagram detailing the NLP Data Pipeline](https://miro.medium.com/v2/resize:fit:1400/format:webp/1*Mj5ugCfpYyR4hS4-gWfp2w.png)
#
# For today, we're really concerned with understanding the `preprocessing` pipeline and how we can implement it with NLTK since it is composed of many steps.
#
# ![Diagram detailing preprocessing steps](https://miro.medium.com/v2/resize:fit:1400/format:webp/1*HMskuHrmqBdQXus2VNvZ0g.png)

# %% [markdown]
# # Tokenization
#
# There's a variety of tokenization types/approaches that can be used -- the tutorial at [Geeks for Geeks](https://www.geeksforgeeks.org/nlp/nlp-how-tokenizing-text-sentence-words-works/) has a very good breakdown of these different types.
#
# When we are talking about the different *types* of tokenization there's five key ones that some could be thinking of or referring to as shown below:
#
# ![](https://media.geeksforgeeks.org/wp-content/uploads/20250530170340097187/Types-of-Tokenization-in-NLP.webp)
#
# How we do that tokenization is the approach and there's five major approaches (although in this course we're really talking/going to use the first three and eventually the fourth).
#
# ![](https://media.geeksforgeeks.org/wp-content/uploads/20250530170339847001/Popular-Approaches-of-Tokenization.webp)

# %% [markdown]
# # Back to Othello
#
# So now let's dig into tokenization and see the actual examples.

# %%
fulltext = open('../../data/Othello.txt').read()

# %%
# !conda install nltk -y
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - conda-forge
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.5.0
#     latest version: 25.7.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - nltk
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-2.136                 |         openblas          17 KB  conda-forge
#     blas-devel-3.9.0           |36_h1ea3ea9_openblas          17 KB  conda-forge
#     ca-certificates-2025.8.3   |       hbd8a1cb_0         151 KB  conda-forge
#     certifi-2025.8.3           |     pyhd8ed1ab_0         155 KB  conda-forge
#     libblas-3.9.0              |36_h4a7cf45_openblas          17 KB  conda-forge
#     libcblas-3.9.0             |36_h0358290_openblas          17 KB  conda-forge
#     libgcc-15.1.0              |       h767d61c_5         805 KB  conda-forge
#     libgcc-ng-15.1.0           |       h69a702a_5          29 KB  conda-forge
#     libgfortran-15.1.0         |       h69a702a_5          28 KB  conda-forge
#     libgfortran-ng-15.1.0      |       h69a702a_5          29 KB  conda-forge
#     libgfortran5-15.1.0        |       hcea5267_5         1.5 MB  conda-forge
#     libgomp-15.1.0             |       h767d61c_5         437 KB  conda-forge
#     liblapack-3.9.0            |36_h47877c9_openblas          17 KB  conda-forge
#     liblapacke-3.9.0           |36_h6ae95b6_openblas          17 KB  conda-forge
#     libopenblas-0.3.30         |pthreads_h94d23a6_2         5.7 MB  conda-forge
#     libstdcxx-15.1.0           |       h8f9b012_5         3.7 MB  conda-forge
#     libstdcxx-ng-15.1.0        |       h4852527_5          29 KB  conda-forge
#     nltk-3.9.1                 |     pyhd8ed1ab_1         1.0 MB  conda-forge
#     openblas-0.3.30            |pthreads_h6ec200e_2         5.8 MB  conda-forge
#     openssl-3.5.3              |       h26f9b46_1         3.0 MB  conda-forge
#     regex-2025.9.18            |  py311h49ec1c0_0         406 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        22.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   libgcc             conda-forge/linux-64::libgcc-15.1.0-h767d61c_5
#   libgfortran        conda-forge/linux-64::libgfortran-15.1.0-h69a702a_5
#   libstdcxx          conda-forge/linux-64::libstdcxx-15.1.0-h8f9b012_5
#   nltk               conda-forge/noarch::nltk-3.9.1-pyhd8ed1ab_1
#   regex              conda-forge/linux-64::regex-2025.9.18-py311h49ec1c0_0
#
# The following packages will be UPDATED:
#
#   blas                                       2.122-openblas --> 2.136-openblas
#   blas-devel                      3.9.0-22_linux64_openblas --> 3.9.0-36_h1ea3ea9_openblas
#   ca-certificates    conda-forge/linux-64::ca-certificates~ --> conda-forge/noarch::ca-certificates-2025.8.3-hbd8a1cb_0
#   certifi                             2024.6.2-pyhd8ed1ab_0 --> 2025.8.3-pyhd8ed1ab_0
#   libblas                         3.9.0-22_linux64_openblas --> 3.9.0-36_h4a7cf45_openblas
#   libcblas                        3.9.0-22_linux64_openblas --> 3.9.0-36_h0358290_openblas
#   libgcc-ng                               14.1.0-h77fa898_0 --> 15.1.0-h69a702a_5
#   libgfortran-ng                          14.1.0-h69a702a_0 --> 15.1.0-h69a702a_5
#   libgfortran5                            14.1.0-hc5f4f2c_0 --> 15.1.0-hcea5267_5
#   libgomp                                 14.1.0-h77fa898_0 --> 15.1.0-h767d61c_5
#   liblapack                       3.9.0-22_linux64_openblas --> 3.9.0-36_h47877c9_openblas
#   liblapacke                      3.9.0-22_linux64_openblas --> 3.9.0-36_h6ae95b6_openblas
#   libopenblas                    0.3.27-pthreads_h413a1c8_0 --> 0.3.30-pthreads_h94d23a6_2
#   libstdcxx-ng                            14.1.0-hc0a3c3a_0 --> 15.1.0-h4852527_5
#   openblas                       0.3.27-pthreads_h7a3da1a_0 --> 0.3.30-pthreads_h6ec200e_2
#   openssl                                  3.3.1-h4ab18f5_1 --> 3.5.3-h26f9b46_1
#
#
#
# Downloading and Extracting Packages:
# openblas-0.3.30      | 5.8 MB    |                                       |   0%
# libopenblas-0.3.30   | 5.7 MB    |                                       |   0%
#
# libstdcxx-15.1.0     | 3.7 MB    |                                       |   0%
#
#
# openssl-3.5.3        | 3.0 MB    |                                       |   0%
#
#
#
# libgfortran5-15.1.0  | 1.5 MB    |                                       |   0%
#
#
#
#
# nltk-3.9.1           | 1.0 MB    |                                       |   0%
#
#
#
#
#
# libgcc-15.1.0        | 805 KB    |                                       |   0%
#
#
#
#
#
#
# libgomp-15.1.0       | 437 KB    |                                       |   0%
#
#
#
#
#
#
#
# regex-2025.9.18      | 406 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# certifi-2025.8.3     | 155 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 151 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# libstdcxx-ng-15.1.0  | 29 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# libgfortran-ng-15.1. | 29 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-15.1.0     | 29 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran-15.1.0   | 28 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# liblapacke-3.9.0     | 17 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libblas-3.9.0        | 17 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# liblapack-3.9.0      | 17 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcblas-3.9.0       | 17 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# blas-devel-3.9.0     | 17 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# blas-2.136           | 17 KB     |                                       |   0%
# openblas-0.3.30      | 5.8 MB    | 1                                     |   0%
#
#
# openssl-3.5.3        | 3.0 MB    | 1                                     |   1%
#
# libstdcxx-15.1.0     | 3.7 MB    | 1                                     |   0%
#
#
#
# libgfortran5-15.1.0  | 1.5 MB    | 3                                     |   1%
# openblas-0.3.30      | 5.8 MB    | ############                          |  32%
#
#
# openssl-3.5.3        | 3.0 MB    | ########################              |  65%
#
# libstdcxx-15.1.0     | 3.7 MB    | #####################6                |  58%
#
#
#
#
#
# libgcc-15.1.0        | 805 KB    | 7                                     |   2%
#
#
#
#
# nltk-3.9.1           | 1.0 MB    | 5                                     |   2%
#
#
#
#
#
#
# libgomp-15.1.0       | 437 KB    | #3                                    |   4%
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 151 KB    | ###9                                  |  11%
#
#
#
#
#
#
#
# regex-2025.9.18      | 406 KB    | #4                                    |   4%
#
#
#
#
#
#
#
#
#
#
# libstdcxx-ng-15.1.0  | 29 KB     | ####################7                 |  56%
#
#
#
#
#
#
#
#
# certifi-2025.8.3     | 155 KB    | ###8                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
# libgfortran-ng-15.1. | 29 KB     | ####################7                 |  56%
#
#
#
# libgfortran5-15.1.0  | 1.5 MB    | ##################################### | 100%
#
#
#
# libgfortran5-15.1.0  | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-15.1.0     | 29 KB     | ####################7                 |  56%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran-15.1.0   | 28 KB     | ####################7                 |  56%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# liblapacke-3.9.0     | 17 KB     | ##################################7   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# liblapack-3.9.0      | 17 KB     | ##################################8   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libblas-3.9.0        | 17 KB     | ##################################7   |  94%
#
#
#
#
#
#
# libgomp-15.1.0       | 437 KB    | ##################################### | 100%
#
#
#
#
#
#
# libgomp-15.1.0       | 437 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# blas-devel-3.9.0     | 17 KB     | ##################################8   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcblas-3.9.0       | 17 KB     | ##################################8   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# blas-2.136           | 17 KB     | ##################################9   |  94%
#
# libstdcxx-15.1.0     | 3.7 MB    | ##################################### | 100%
#
# libstdcxx-15.1.0     | 3.7 MB    | ##################################### | 100%
#
#
# openssl-3.5.3        | 3.0 MB    | ##################################### | 100%
#
#
#
#
#
# libgcc-15.1.0        | 805 KB    | ##################################### | 100%
#
#
#
#
#
# libgcc-15.1.0        | 805 KB    | ##################################### | 100%
# libopenblas-0.3.30   | 5.7 MB    | ##################################### | 100%
# libopenblas-0.3.30   | 5.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 151 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 151 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# libstdcxx-ng-15.1.0  | 29 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# libstdcxx-ng-15.1.0  | 29 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# libgfortran-ng-15.1. | 29 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# libgfortran-ng-15.1. | 29 KB     | ##################################### | 100%
#
#
#
#
# nltk-3.9.1           | 1.0 MB    | ##################################### | 100%
#
#
#
#
# nltk-3.9.1           | 1.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
# regex-2025.9.18      | 406 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# regex-2025.9.18      | 406 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# certifi-2025.8.3     | 155 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# certifi-2025.8.3     | 155 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-15.1.0     | 29 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-15.1.0     | 29 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran-15.1.0   | 28 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran-15.1.0   | 28 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# liblapacke-3.9.0     | 17 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# liblapack-3.9.0      | 17 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libblas-3.9.0        | 17 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# blas-devel-3.9.0     | 17 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcblas-3.9.0       | 17 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
from nltk import tokenize

dir(tokenize)
# Out:
# ['BlanklineTokenizer',
#  'LegalitySyllableTokenizer',
#  'LineTokenizer',
#  'MWETokenizer',
#  'NLTKWordTokenizer',
#  'PunktSentenceTokenizer',
#  'PunktTokenizer',
#  'RegexpTokenizer',
#  'ReppTokenizer',
#  'SExprTokenizer',
#  'SpaceTokenizer',
#  'StanfordSegmenter',
#  'SyllableTokenizer',
#  'TabTokenizer',
#  'TextTilingTokenizer',
#  'ToktokTokenizer',
#  'TreebankWordDetokenizer',
#  'TreebankWordTokenizer',
#  'TweetTokenizer',
#  'WhitespaceTokenizer',
#  'WordPunctTokenizer',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_get_punkt_tokenizer',
#  '_treebank_word_tokenizer',
#  'api',
#  'blankline_tokenize',
#  'casual',
#  'casual_tokenize',
#  'destructive',
#  'functools',
#  'legality_principle',
#  'line_tokenize',
#  'load',
#  'mwe',
#  'punkt',
#  're',
#  'regexp',
#  'regexp_span_tokenize',
#  'regexp_tokenize',
#  'repp',
#  'sent_tokenize',
#  'sexpr',
#  'sexpr_tokenize',
#  'simple',
#  'sonority_sequencing',
#  'stanford_segmenter',
#  'string_span_tokenize',
#  'texttiling',
#  'toktok',
#  'treebank',
#  'util',
#  'word_tokenize',
#  'wordpunct_tokenize']

# %%
tokenize.blankline_tokenize(fulltext[:500])
# Out:
# ['SCENE: Venice and Cyprus',
#  'ACT I. SCENE I.\nVenice. A street.',
#  'Enter Roderigo and Iago.',
#  "RODERIGO. Tush, never tell me! I take it much unkindly\n    That thou, Iago, who hast had my purse\n    As if the strings were thine, shouldst know of this.\n  IAGO. 'Sblood, but you will not hear me.\n    If ever I did dream of such a matter,\n    Abhor me.\n  RODERIGO. Thou told'st me thou didst hold him in thy hate.\n  IAGO. Despise me, if I do not. Three great ones of the city,\n    In personal suit to make me h"]

# %%
tokenize.casual_tokenize(fulltext[:500])
# Out:
# ['SCENE',
#  ':',
#  'Venice',
#  'and',
#  'Cyprus',
#  'ACT',
#  'I',
#  '.',
#  'SCENE',
#  'I',
#  '.',
#  'Venice',
#  '.',
#  'A',
#  'street',
#  '.',
#  'Enter',
#  'Roderigo',
#  'and',
#  'Iago',
#  '.',
#  'RODERIGO',
#  '.',
#  'Tush',
#  ',',
#  'never',
#  'tell',
#  'me',
#  '!',
#  'I',
#  'take',
#  'it',
#  'much',
#  'unkindly',
#  'That',
#  'thou',
#  ',',
#  'Iago',
#  ',',
#  'who',
#  'hast',
#  'had',
#  'my',
#  'purse',
#  'As',
#  'if',
#  'the',
#  'strings',
#  'were',
#  'thine',
#  ',',
#  'shouldst',
#  'know',
#  'of',
#  'this',
#  '.',
#  'IAGO',
#  '.',
#  "'",
#  'Sblood',
#  ',',
#  'but',
#  'you',
#  'will',
#  'not',
#  'hear',
#  'me',
#  '.',
#  'If',
#  'ever',
#  'I',
#  'did',
#  'dream',
#  'of',
#  'such',
#  'a',
#  'matter',
#  ',',
#  'Abhor',
#  'me',
#  '.',
#  'RODERIGO',
#  '.',
#  'Thou',
#  "told'st",
#  'me',
#  'thou',
#  'didst',
#  'hold',
#  'him',
#  'in',
#  'thy',
#  'hate',
#  '.',
#  'IAGO',
#  '.',
#  'Despise',
#  'me',
#  ',',
#  'if',
#  'I',
#  'do',
#  'not',
#  '.',
#  'Three',
#  'great',
#  'ones',
#  'of',
#  'the',
#  'city',
#  ',',
#  'In',
#  'personal',
#  'suit',
#  'to',
#  'make',
#  'me',
#  'h']

# %%
tokenize.line_tokenize(fulltext[:500])
# Out:
# ['SCENE: Venice and Cyprus',
#  'ACT I. SCENE I.',
#  'Venice. A street.',
#  'Enter Roderigo and Iago.',
#  '  RODERIGO. Tush, never tell me! I take it much unkindly',
#  '    That thou, Iago, who hast had my purse',
#  '    As if the strings were thine, shouldst know of this.',
#  "  IAGO. 'Sblood, but you will not hear me.",
#  '    If ever I did dream of such a matter,',
#  '    Abhor me.',
#  "  RODERIGO. Thou told'st me thou didst hold him in thy hate.",
#  '  IAGO. Despise me, if I do not. Three great ones of the city,',
#  '    In personal suit to make me h']

# %%
[x for x in tokenize.regexp_span_tokenize(fulltext[:500], '\w+')]
# Out:
# [(5, 7),
#  (13, 14),
#  (17, 18),
#  (24, 26),
#  (29, 30),
#  (31, 33),
#  (38, 39),
#  (40, 42),
#  (48, 50),
#  (51, 52),
#  (58, 61),
#  (66, 67),
#  (75, 76),
#  (79, 80),
#  (84, 89),
#  (97, 99),
#  (103, 105),
#  (110, 111),
#  (115, 116),
#  (118, 120),
#  (121, 122),
#  (126, 127),
#  (129, 130),
#  (134, 135),
#  (143, 148),
#  (152, 153),
#  (157, 159),
#  (163, 165),
#  (168, 169),
#  (173, 174),
#  (177, 178),
#  (180, 181),
#  (186, 191),
#  (193, 194),
#  (196, 197),
#  (200, 201),
#  (208, 209),
#  (213, 214),
#  (219, 221),
#  (229, 230),
#  (234, 235),
#  (237, 238),
#  (242, 246),
#  (250, 253),
#  (259, 261),
#  (264, 265),
#  (268, 269),
#  (273, 274),
#  (277, 278),
#  (282, 283),
#  (285, 291),
#  (293, 294),
#  (298, 299),
#  (300, 301),
#  (304, 305),
#  (310, 311),
#  (313, 314),
#  (318, 319),
#  (320, 321),
#  (327, 333),
#  (338, 339),
#  (341, 345),
#  (353, 355),
#  (359, 360),
#  (364, 365),
#  (367, 368),
#  (370, 371),
#  (375, 376),
#  (381, 382),
#  (386, 387),
#  (390, 391),
#  (393, 394),
#  (397, 398),
#  (402, 406),
#  (410, 412),
#  (419, 420),
#  (422, 424),
#  (426, 427),
#  (428, 429),
#  (431, 432),
#  (435, 437),
#  (442, 443),
#  (448, 449),
#  (453, 454),
#  (456, 457),
#  (460, 461),
#  (465, 471),
#  (473, 474),
#  (482, 483),
#  (487, 488),
#  (490, 491),
#  (495, 496),
#  (498, 499),
#  (500, 500)]

# %%
tokenize.regexp_tokenize(fulltext[:500], '\w+')
# Out:
# ['SCENE',
#  'Venice',
#  'and',
#  'Cyprus',
#  'ACT',
#  'I',
#  'SCENE',
#  'I',
#  'Venice',
#  'A',
#  'street',
#  'Enter',
#  'Roderigo',
#  'and',
#  'Iago',
#  'RODERIGO',
#  'Tush',
#  'never',
#  'tell',
#  'me',
#  'I',
#  'take',
#  'it',
#  'much',
#  'unkindly',
#  'That',
#  'thou',
#  'Iago',
#  'who',
#  'hast',
#  'had',
#  'my',
#  'purse',
#  'As',
#  'if',
#  'the',
#  'strings',
#  'were',
#  'thine',
#  'shouldst',
#  'know',
#  'of',
#  'this',
#  'IAGO',
#  'Sblood',
#  'but',
#  'you',
#  'will',
#  'not',
#  'hear',
#  'me',
#  'If',
#  'ever',
#  'I',
#  'did',
#  'dream',
#  'of',
#  'such',
#  'a',
#  'matter',
#  'Abhor',
#  'me',
#  'RODERIGO',
#  'Thou',
#  'told',
#  'st',
#  'me',
#  'thou',
#  'didst',
#  'hold',
#  'him',
#  'in',
#  'thy',
#  'hate',
#  'IAGO',
#  'Despise',
#  'me',
#  'if',
#  'I',
#  'do',
#  'not',
#  'Three',
#  'great',
#  'ones',
#  'of',
#  'the',
#  'city',
#  'In',
#  'personal',
#  'suit',
#  'to',
#  'make',
#  'me',
#  'h']

# %%
tokenize.sent_tokenize(fulltext[:500])
# Out:
# ['SCENE: Venice and Cyprus\n\nACT I.',
#  'SCENE I.\nVenice.',
#  'A street.',
#  'Enter Roderigo and Iago.',
#  'RODERIGO.',
#  'Tush, never tell me!',
#  'I take it much unkindly\n    That thou, Iago, who hast had my purse\n    As if the strings were thine, shouldst know of this.',
#  'IAGO.',
#  "'Sblood, but you will not hear me.",
#  'If ever I did dream of such a matter,\n    Abhor me.',
#  'RODERIGO.',
#  "Thou told'st me thou didst hold him in thy hate.",
#  'IAGO.',
#  'Despise me, if I do not.',
#  'Three great ones of the city,\n    In personal suit to make me h']

# %%
tokenize.word_tokenize(fulltext[:500])
# Out:
# ['SCENE',
#  ':',
#  'Venice',
#  'and',
#  'Cyprus',
#  'ACT',
#  'I',
#  '.',
#  'SCENE',
#  'I.',
#  'Venice',
#  '.',
#  'A',
#  'street',
#  '.',
#  'Enter',
#  'Roderigo',
#  'and',
#  'Iago',
#  '.',
#  'RODERIGO',
#  '.',
#  'Tush',
#  ',',
#  'never',
#  'tell',
#  'me',
#  '!',
#  'I',
#  'take',
#  'it',
#  'much',
#  'unkindly',
#  'That',
#  'thou',
#  ',',
#  'Iago',
#  ',',
#  'who',
#  'hast',
#  'had',
#  'my',
#  'purse',
#  'As',
#  'if',
#  'the',
#  'strings',
#  'were',
#  'thine',
#  ',',
#  'shouldst',
#  'know',
#  'of',
#  'this',
#  '.',
#  'IAGO',
#  '.',
#  "'Sblood",
#  ',',
#  'but',
#  'you',
#  'will',
#  'not',
#  'hear',
#  'me',
#  '.',
#  'If',
#  'ever',
#  'I',
#  'did',
#  'dream',
#  'of',
#  'such',
#  'a',
#  'matter',
#  ',',
#  'Abhor',
#  'me',
#  '.',
#  'RODERIGO',
#  '.',
#  'Thou',
#  "told'st",
#  'me',
#  'thou',
#  'didst',
#  'hold',
#  'him',
#  'in',
#  'thy',
#  'hate',
#  '.',
#  'IAGO',
#  '.',
#  'Despise',
#  'me',
#  ',',
#  'if',
#  'I',
#  'do',
#  'not',
#  '.',
#  'Three',
#  'great',
#  'ones',
#  'of',
#  'the',
#  'city',
#  ',',
#  'In',
#  'personal',
#  'suit',
#  'to',
#  'make',
#  'me',
#  'h']

# %% [markdown]
# # Stemming
#
# Stemming is the removal of conjugations to get at the base form of a word (i.e., so `running` and `run` will be recognized as the same word). As is shown in the associated research paper readings, we are performing these changes algorithmically which means that there will be variations depending on the algorithm chosen.

# %%
from nltk import stem, tokenize

wordlist = tokenize.word_tokenize(fulltext[:500])


dir(stem)
# Out:
# ['ARLSTem',
#  'ARLSTem2',
#  'Cistem',
#  'ISRIStemmer',
#  'LancasterStemmer',
#  'PorterStemmer',
#  'RSLPStemmer',
#  'RegexpStemmer',
#  'SnowballStemmer',
#  'StemmerI',
#  'WordNetLemmatizer',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'api',
#  'arlstem',
#  'arlstem2',
#  'cistem',
#  'isri',
#  'lancaster',
#  'porter',
#  'regexp',
#  'rslp',
#  'snowball',
#  'util',
#  'wordnet']

# %%
ls = stem.LancasterStemmer()

print([ls.stem(w) for w in wordlist])
# Out:
# ['scen', ':', 'ven', 'and', 'cypr', 'act', 'i', '.', 'scen', 'i.', 'ven', '.', 'a', 'street', '.', 'ent', 'roderigo', 'and', 'iago', '.', 'roderigo', '.', 'tush', ',', 'nev', 'tel', 'me', '!', 'i', 'tak', 'it', 'much', 'unkind', 'that', 'thou', ',', 'iago', ',', 'who', 'hast', 'had', 'my', 'purs', 'as', 'if', 'the', 'strings', 'wer', 'thin', ',', 'shouldst', 'know', 'of', 'thi', '.', 'iago', '.', "'sblood", ',', 'but', 'you', 'wil', 'not', 'hear', 'me', '.', 'if', 'ev', 'i', 'did', 'dream', 'of', 'such', 'a', 'mat', ',', 'abh', 'me', '.', 'roderigo', '.', 'thou', "told'st", 'me', 'thou', 'didst', 'hold', 'him', 'in', 'thy', 'hat', '.', 'iago', '.', 'desp', 'me', ',', 'if', 'i', 'do', 'not', '.', 'three', 'gre', 'on', 'of', 'the', 'city', ',', 'in', 'person', 'suit', 'to', 'mak', 'me', 'h']

# %%
ps = stem.PorterStemmer()

print([ps.stem(w) for w in wordlist])
# Out:
# ['scene', ':', 'venic', 'and', 'cypru', 'act', 'i', '.', 'scene', 'i.', 'venic', '.', 'a', 'street', '.', 'enter', 'roderigo', 'and', 'iago', '.', 'roderigo', '.', 'tush', ',', 'never', 'tell', 'me', '!', 'i', 'take', 'it', 'much', 'unkindli', 'that', 'thou', ',', 'iago', ',', 'who', 'hast', 'had', 'my', 'purs', 'as', 'if', 'the', 'string', 'were', 'thine', ',', 'shouldst', 'know', 'of', 'thi', '.', 'iago', '.', "'sblood", ',', 'but', 'you', 'will', 'not', 'hear', 'me', '.', 'if', 'ever', 'i', 'did', 'dream', 'of', 'such', 'a', 'matter', ',', 'abhor', 'me', '.', 'roderigo', '.', 'thou', "told'st", 'me', 'thou', 'didst', 'hold', 'him', 'in', 'thi', 'hate', '.', 'iago', '.', 'despis', 'me', ',', 'if', 'i', 'do', 'not', '.', 'three', 'great', 'one', 'of', 'the', 'citi', ',', 'in', 'person', 'suit', 'to', 'make', 'me', 'h']

# %%
ss = stem.SnowballStemmer('english')

print([ss.stem(w) for w in wordlist])
# Out:
# ['scene', ':', 'venic', 'and', 'cyprus', 'act', 'i', '.', 'scene', 'i.', 'venic', '.', 'a', 'street', '.', 'enter', 'roderigo', 'and', 'iago', '.', 'roderigo', '.', 'tush', ',', 'never', 'tell', 'me', '!', 'i', 'take', 'it', 'much', 'unkind', 'that', 'thou', ',', 'iago', ',', 'who', 'hast', 'had', 'my', 'purs', 'as', 'if', 'the', 'string', 'were', 'thine', ',', 'shouldst', 'know', 'of', 'this', '.', 'iago', '.', 'sblood', ',', 'but', 'you', 'will', 'not', 'hear', 'me', '.', 'if', 'ever', 'i', 'did', 'dream', 'of', 'such', 'a', 'matter', ',', 'abhor', 'me', '.', 'roderigo', '.', 'thou', "told'st", 'me', 'thou', 'didst', 'hold', 'him', 'in', 'thi', 'hate', '.', 'iago', '.', 'despis', 'me', ',', 'if', 'i', 'do', 'not', '.', 'three', 'great', 'one', 'of', 'the', 'citi', ',', 'in', 'person', 'suit', 'to', 'make', 'me', 'h']

# %%
import nltk
nltk.download('wordnet')

ws = stem.WordNetLemmatizer()

print([ws.lemmatize(w) for w in wordlist])
# Out:
# [nltk_data] Downloading package wordnet to /home/jovyan/nltk_data...
# ['SCENE', ':', 'Venice', 'and', 'Cyprus', 'ACT', 'I', '.', 'SCENE', 'I.', 'Venice', '.', 'A', 'street', '.', 'Enter', 'Roderigo', 'and', 'Iago', '.', 'RODERIGO', '.', 'Tush', ',', 'never', 'tell', 'me', '!', 'I', 'take', 'it', 'much', 'unkindly', 'That', 'thou', ',', 'Iago', ',', 'who', 'hast', 'had', 'my', 'purse', 'As', 'if', 'the', 'string', 'were', 'thine', ',', 'shouldst', 'know', 'of', 'this', '.', 'IAGO', '.', "'Sblood", ',', 'but', 'you', 'will', 'not', 'hear', 'me', '.', 'If', 'ever', 'I', 'did', 'dream', 'of', 'such', 'a', 'matter', ',', 'Abhor', 'me', '.', 'RODERIGO', '.', 'Thou', "told'st", 'me', 'thou', 'didst', 'hold', 'him', 'in', 'thy', 'hate', '.', 'IAGO', '.', 'Despise', 'me', ',', 'if', 'I', 'do', 'not', '.', 'Three', 'great', 'one', 'of', 'the', 'city', ',', 'In', 'personal', 'suit', 'to', 'make', 'me', 'h']

# %% [markdown]
# # Stop words
#
# Stop words can be relatively simple  -- we can use pre-built dictionaries of stop words from NLTK

# %%
import nltk 

nltk.download('stopwords')

from nltk.corpus import stopwords

list(set(stopwords.words('english')))[:10]
# Out:
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['such',
#  'hers',
#  "aren't",
#  'yours',
#  'under',
#  "you'd",
#  'some',
#  "it'd",
#  'by',
#  "we'd"]

# %% [markdown]
# The most computationally efficient way to clean out stopwords is to use it as the set variable

# %%
from nltk.corpus import stopwords 
from nltk import stem, tokenize


fulltext = open('../../data/Othello.txt').read()
wordlist = tokenize.word_tokenize(fulltext[:500])


stopwords = set(stopwords.words('english'))


len(wordlist), len([w for w in wordlist if w not in stopwords])
# Out:
# (116, 83)

# %% [markdown]
# # Implementing a data preprocessing routine
#
# We still want to analyze character dialogue today, in fact we want to expand beyond just Iago and Othello.
#
# Plan and execute your *normalization* and *tokenization* pipeline as a function so that we can easily modify it and expand our preprocessing pipeline

# %%
## Develop a preprocessing function for the text that makes it easy to access the cleaned dialogue forr every character

# %% [markdown]
# # Comparing dialogue
#
# We can easily start to dig into whether the number of words spoken would really designate one character as being the 'main' character in a play.
#
# Let's compare all of the characters and how much they speak and graph the rank/frequency plots

# %%
#Exercise

# %% [markdown]
# Now -- do we think that these differences are significant? How could we test for them?

# %%
#Exercise

# %% [markdown]
# # Extending beyond a bag of words
#
# So far we have only dealt with what are called `uni-grams` (i.e. single word, bag of words). Bigrams and trigrams are also a part of the picture and are a different tokenization approach.
#
# We didn't cover them at the start, but we can access them through the n-grams functions.

# %%
list(nltk.bigrams(fulltext[:500]) )
# Out:
# [('S', 'C'),
#  ('C', 'E'),
#  ('E', 'N'),
#  ('N', 'E'),
#  ('E', ':'),
#  (':', ' '),
#  (' ', 'V'),
#  ('V', 'e'),
#  ('e', 'n'),
#  ('n', 'i'),
#  ('i', 'c'),
#  ('c', 'e'),
#  ('e', ' '),
#  (' ', 'a'),
#  ('a', 'n'),
#  ('n', 'd'),
#  ('d', ' '),
#  (' ', 'C'),
#  ('C', 'y'),
#  ('y', 'p'),
#  ('p', 'r'),
#  ('r', 'u'),
#  ('u', 's'),
#  ('s', '\n'),
#  ('\n', '\n'),
#  ('\n', 'A'),
#  ('A', 'C'),
#  ('C', 'T'),
#  ('T', ' '),
#  (' ', 'I'),
#  ('I', '.'),
#  ('.', ' '),
#  (' ', 'S'),
#  ('S', 'C'),
#  ('C', 'E'),
#  ('E', 'N'),
#  ('N', 'E'),
#  ('E', ' '),
#  (' ', 'I'),
#  ('I', '.'),
#  ('.', '\n'),
#  ('\n', 'V'),
#  ('V', 'e'),
#  ('e', 'n'),
#  ('n', 'i'),
#  ('i', 'c'),
#  ('c', 'e'),
#  ('e', '.'),
#  ('.', ' '),
#  (' ', 'A'),
#  ('A', ' '),
#  (' ', 's'),
#  ('s', 't'),
#  ('t', 'r'),
#  ('r', 'e'),
#  ('e', 'e'),
#  ('e', 't'),
#  ('t', '.'),
#  ('.', '\n'),
#  ('\n', '\n'),
#  ('\n', 'E'),
#  ('E', 'n'),
#  ('n', 't'),
#  ('t', 'e'),
#  ('e', 'r'),
#  ('r', ' '),
#  (' ', 'R'),
#  ('R', 'o'),
#  ('o', 'd'),
#  ('d', 'e'),
#  ('e', 'r'),
#  ('r', 'i'),
#  ('i', 'g'),
#  ('g', 'o'),
#  ('o', ' '),
#  (' ', 'a'),
#  ('a', 'n'),
#  ('n', 'd'),
#  ('d', ' '),
#  (' ', 'I'),
#  ('I', 'a'),
#  ('a', 'g'),
#  ('g', 'o'),
#  ('o', '.'),
#  ('.', '\n'),
#  ('\n', '\n'),
#  ('\n', ' '),
#  (' ', ' '),
#  (' ', 'R'),
#  ('R', 'O'),
#  ('O', 'D'),
#  ('D', 'E'),
#  ('E', 'R'),
#  ('R', 'I'),
#  ('I', 'G'),
#  ('G', 'O'),
#  ('O', '.'),
#  ('.', ' '),
#  (' ', 'T'),
#  ('T', 'u'),
#  ('u', 's'),
#  ('s', 'h'),
#  ('h', ','),
#  (',', ' '),
#  (' ', 'n'),
#  ('n', 'e'),
#  ('e', 'v'),
#  ('v', 'e'),
#  ('e', 'r'),
#  ('r', ' '),
#  (' ', 't'),
#  ('t', 'e'),
#  ('e', 'l'),
#  ('l', 'l'),
#  ('l', ' '),
#  (' ', 'm'),
#  ('m', 'e'),
#  ('e', '!'),
#  ('!', ' '),
#  (' ', 'I'),
#  ('I', ' '),
#  (' ', 't'),
#  ('t', 'a'),
#  ('a', 'k'),
#  ('k', 'e'),
#  ('e', ' '),
#  (' ', 'i'),
#  ('i', 't'),
#  ('t', ' '),
#  (' ', 'm'),
#  ('m', 'u'),
#  ('u', 'c'),
#  ('c', 'h'),
#  ('h', ' '),
#  (' ', 'u'),
#  ('u', 'n'),
#  ('n', 'k'),
#  ('k', 'i'),
#  ('i', 'n'),
#  ('n', 'd'),
#  ('d', 'l'),
#  ('l', 'y'),
#  ('y', '\n'),
#  ('\n', ' '),
#  (' ', ' '),
#  (' ', ' '),
#  (' ', ' '),
#  (' ', 'T'),
#  ('T', 'h'),
#  ('h', 'a'),
#  ('a', 't'),
#  ('t', ' '),
#  (' ', 't'),
#  ('t', 'h'),
#  ('h', 'o'),
#  ('o', 'u'),
#  ('u', ','),
#  (',', ' '),
#  (' ', 'I'),
#  ('I', 'a'),
#  ('a', 'g'),
#  ('g', 'o'),
#  ('o', ','),
#  (',', ' '),
#  (' ', 'w'),
#  ('w', 'h'),
#  ('h', 'o'),
#  ('o', ' '),
#  (' ', 'h'),
#  ('h', 'a'),
#  ('a', 's'),
#  ('s', 't'),
#  ('t', ' '),
#  (' ', 'h'),
#  ('h', 'a'),
#  ('a', 'd'),
#  ('d', ' '),
#  (' ', 'm'),
#  ('m', 'y'),
#  ('y', ' '),
#  (' ', 'p'),
#  ('p', 'u'),
#  ('u', 'r'),
#  ('r', 's'),
#  ('s', 'e'),
#  ('e', '\n'),
#  ('\n', ' '),
#  (' ', ' '),
#  (' ', ' '),
#  (' ', ' '),
#  (' ', 'A'),
#  ('A', 's'),
#  ('s', ' '),
#  (' ', 'i'),
#  ('i', 'f'),
#  ('f', ' '),
#  (' ', 't'),
#  ('t', 'h'),
#  ('h', 'e'),
#  ('e', ' '),
#  (' ', 's'),
#  ('s', 't'),
#  ('t', 'r'),
#  ('r', 'i'),
#  ('i', 'n'),
#  ('n', 'g'),
#  ('g', 's'),
#  ('s', ' '),
#  (' ', 'w'),
#  ('w', 'e'),
#  ('e', 'r'),
#  ('r', 'e'),
#  ('e', ' '),
#  (' ', 't'),
#  ('t', 'h'),
#  ('h', 'i'),
#  ('i', 'n'),
#  ('n', 'e'),
#  ('e', ','),
#  (',', ' '),
#  (' ', 's'),
#  ('s', 'h'),
#  ('h', 'o'),
#  ('o', 'u'),
#  ('u', 'l'),
#  ('l', 'd'),
#  ('d', 's'),
#  ('s', 't'),
#  ('t', ' '),
#  (' ', 'k'),
#  ('k', 'n'),
#  ('n', 'o'),
#  ('o', 'w'),
#  ('w', ' '),
#  (' ', 'o'),
#  ('o', 'f'),
#  ('f', ' '),
#  (' ', 't'),
#  ('t', 'h'),
#  ('h', 'i'),
#  ('i', 's'),
#  ('s', '.'),
#  ('.', '\n'),
#  ('\n', ' '),
#  (' ', ' '),
#  (' ', 'I'),
#  ('I', 'A'),
#  ('A', 'G'),
#  ('G', 'O'),
#  ('O', '.'),
#  ('.', ' '),
#  (' ', "'"),
#  ("'", 'S'),
#  ('S', 'b'),
#  ('b', 'l'),
#  ('l', 'o'),
#  ('o', 'o'),
#  ('o', 'd'),
#  ('d', ','),
#  (',', ' '),
#  (' ', 'b'),
#  ('b', 'u'),
#  ('u', 't'),
#  ('t', ' '),
#  (' ', 'y'),
#  ('y', 'o'),
#  ('o', 'u'),
#  ('u', ' '),
#  (' ', 'w'),
#  ('w', 'i'),
#  ('i', 'l'),
#  ('l', 'l'),
#  ('l', ' '),
#  (' ', 'n'),
#  ('n', 'o'),
#  ('o', 't'),
#  ('t', ' '),
#  (' ', 'h'),
#  ('h', 'e'),
#  ('e', 'a'),
#  ('a', 'r'),
#  ('r', ' '),
#  (' ', 'm'),
#  ('m', 'e'),
#  ('e', '.'),
#  ('.', '\n'),
#  ('\n', ' '),
#  (' ', ' '),
#  (' ', ' '),
#  (' ', ' '),
#  (' ', 'I'),
#  ('I', 'f'),
#  ('f', ' '),
#  (' ', 'e'),
#  ('e', 'v'),
#  ('v', 'e'),
#  ('e', 'r'),
#  ('r', ' '),
#  (' ', 'I'),
#  ('I', ' '),
#  (' ', 'd'),
#  ('d', 'i'),
#  ('i', 'd'),
#  ('d', ' '),
#  (' ', 'd'),
#  ('d', 'r'),
#  ('r', 'e'),
#  ('e', 'a'),
#  ('a', 'm'),
#  ('m', ' '),
#  (' ', 'o'),
#  ('o', 'f'),
#  ('f', ' '),
#  (' ', 's'),
#  ('s', 'u'),
#  ('u', 'c'),
#  ('c', 'h'),
#  ('h', ' '),
#  (' ', 'a'),
#  ('a', ' '),
#  (' ', 'm'),
#  ('m', 'a'),
#  ('a', 't'),
#  ('t', 't'),
#  ('t', 'e'),
#  ('e', 'r'),
#  ('r', ','),
#  (',', '\n'),
#  ('\n', ' '),
#  (' ', ' '),
#  (' ', ' '),
#  (' ', ' '),
#  (' ', 'A'),
#  ('A', 'b'),
#  ('b', 'h'),
#  ('h', 'o'),
#  ('o', 'r'),
#  ('r', ' '),
#  (' ', 'm'),
#  ('m', 'e'),
#  ('e', '.'),
#  ('.', '\n'),
#  ('\n', ' '),
#  (' ', ' '),
#  (' ', 'R'),
#  ('R', 'O'),
#  ('O', 'D'),
#  ('D', 'E'),
#  ('E', 'R'),
#  ('R', 'I'),
#  ('I', 'G'),
#  ('G', 'O'),
#  ('O', '.'),
#  ('.', ' '),
#  (' ', 'T'),
#  ('T', 'h'),
#  ('h', 'o'),
#  ('o', 'u'),
#  ('u', ' '),
#  (' ', 't'),
#  ('t', 'o'),
#  ('o', 'l'),
#  ('l', 'd'),
#  ('d', "'"),
#  ("'", 's'),
#  ('s', 't'),
#  ('t', ' '),
#  (' ', 'm'),
#  ('m', 'e'),
#  ('e', ' '),
#  (' ', 't'),
#  ('t', 'h'),
#  ('h', 'o'),
#  ('o', 'u'),
#  ('u', ' '),
#  (' ', 'd'),
#  ('d', 'i'),
#  ('i', 'd'),
#  ('d', 's'),
#  ('s', 't'),
#  ('t', ' '),
#  (' ', 'h'),
#  ('h', 'o'),
#  ('o', 'l'),
#  ('l', 'd'),
#  ('d', ' '),
#  (' ', 'h'),
#  ('h', 'i'),
#  ('i', 'm'),
#  ('m', ' '),
#  (' ', 'i'),
#  ('i', 'n'),
#  ('n', ' '),
#  (' ', 't'),
#  ('t', 'h'),
#  ('h', 'y'),
#  ('y', ' '),
#  (' ', 'h'),
#  ('h', 'a'),
#  ('a', 't'),
#  ('t', 'e'),
#  ('e', '.'),
#  ('.', '\n'),
#  ('\n', ' '),
#  (' ', ' '),
#  (' ', 'I'),
#  ('I', 'A'),
#  ('A', 'G'),
#  ('G', 'O'),
#  ('O', '.'),
#  ('.', ' '),
#  (' ', 'D'),
#  ('D', 'e'),
#  ('e', 's'),
#  ('s', 'p'),
#  ('p', 'i'),
#  ('i', 's'),
#  ('s', 'e'),
#  ('e', ' '),
#  (' ', 'm'),
#  ('m', 'e'),
#  ('e', ','),
#  (',', ' '),
#  (' ', 'i'),
#  ('i', 'f'),
#  ('f', ' '),
#  (' ', 'I'),
#  ('I', ' '),
#  (' ', 'd'),
#  ('d', 'o'),
#  ('o', ' '),
#  (' ', 'n'),
#  ('n', 'o'),
#  ('o', 't'),
#  ('t', '.'),
#  ('.', ' '),
#  (' ', 'T'),
#  ('T', 'h'),
#  ('h', 'r'),
#  ('r', 'e'),
#  ('e', 'e'),
#  ('e', ' '),
#  (' ', 'g'),
#  ('g', 'r'),
#  ('r', 'e'),
#  ('e', 'a'),
#  ('a', 't'),
#  ('t', ' '),
#  (' ', 'o'),
#  ('o', 'n'),
#  ('n', 'e'),
#  ('e', 's'),
#  ('s', ' '),
#  (' ', 'o'),
#  ('o', 'f'),
#  ('f', ' '),
#  (' ', 't'),
#  ('t', 'h'),
#  ('h', 'e'),
#  ('e', ' '),
#  (' ', 'c'),
#  ('c', 'i'),
#  ('i', 't'),
#  ('t', 'y'),
#  ('y', ','),
#  (',', '\n'),
#  ('\n', ' '),
#  (' ', ' '),
#  (' ', ' '),
#  (' ', ' '),
#  (' ', 'I'),
#  ('I', 'n'),
#  ('n', ' '),
#  (' ', 'p'),
#  ('p', 'e'),
#  ('e', 'r'),
#  ('r', 's'),
#  ('s', 'o'),
#  ('o', 'n'),
#  ('n', 'a'),
#  ('a', 'l'),
#  ('l', ' '),
#  (' ', 's'),
#  ('s', 'u'),
#  ('u', 'i'),
#  ('i', 't'),
#  ('t', ' '),
#  (' ', 't'),
#  ('t', 'o'),
#  ('o', ' '),
#  (' ', 'm'),
#  ('m', 'a'),
#  ('a', 'k'),
#  ('k', 'e'),
#  ('e', ' '),
#  (' ', 'm'),
#  ('m', 'e'),
#  ('e', ' '),
#  (' ', 'h')]

# %%
list( nltk.bigrams(wordlist) )
# Out:
# [('SCENE', ':'),
#  (':', 'Venice'),
#  ('Venice', 'and'),
#  ('and', 'Cyprus'),
#  ('Cyprus', 'ACT'),
#  ('ACT', 'I'),
#  ('I', '.'),
#  ('.', 'SCENE'),
#  ('SCENE', 'I.'),
#  ('I.', 'Venice'),
#  ('Venice', '.'),
#  ('.', 'A'),
#  ('A', 'street'),
#  ('street', '.'),
#  ('.', 'Enter'),
#  ('Enter', 'Roderigo'),
#  ('Roderigo', 'and'),
#  ('and', 'Iago'),
#  ('Iago', '.'),
#  ('.', 'RODERIGO'),
#  ('RODERIGO', '.'),
#  ('.', 'Tush'),
#  ('Tush', ','),
#  (',', 'never'),
#  ('never', 'tell'),
#  ('tell', 'me'),
#  ('me', '!'),
#  ('!', 'I'),
#  ('I', 'take'),
#  ('take', 'it'),
#  ('it', 'much'),
#  ('much', 'unkindly'),
#  ('unkindly', 'That'),
#  ('That', 'thou'),
#  ('thou', ','),
#  (',', 'Iago'),
#  ('Iago', ','),
#  (',', 'who'),
#  ('who', 'hast'),
#  ('hast', 'had'),
#  ('had', 'my'),
#  ('my', 'purse'),
#  ('purse', 'As'),
#  ('As', 'if'),
#  ('if', 'the'),
#  ('the', 'strings'),
#  ('strings', 'were'),
#  ('were', 'thine'),
#  ('thine', ','),
#  (',', 'shouldst'),
#  ('shouldst', 'know'),
#  ('know', 'of'),
#  ('of', 'this'),
#  ('this', '.'),
#  ('.', 'IAGO'),
#  ('IAGO', '.'),
#  ('.', "'Sblood"),
#  ("'Sblood", ','),
#  (',', 'but'),
#  ('but', 'you'),
#  ('you', 'will'),
#  ('will', 'not'),
#  ('not', 'hear'),
#  ('hear', 'me'),
#  ('me', '.'),
#  ('.', 'If'),
#  ('If', 'ever'),
#  ('ever', 'I'),
#  ('I', 'did'),
#  ('did', 'dream'),
#  ('dream', 'of'),
#  ('of', 'such'),
#  ('such', 'a'),
#  ('a', 'matter'),
#  ('matter', ','),
#  (',', 'Abhor'),
#  ('Abhor', 'me'),
#  ('me', '.'),
#  ('.', 'RODERIGO'),
#  ('RODERIGO', '.'),
#  ('.', 'Thou'),
#  ('Thou', "told'st"),
#  ("told'st", 'me'),
#  ('me', 'thou'),
#  ('thou', 'didst'),
#  ('didst', 'hold'),
#  ('hold', 'him'),
#  ('him', 'in'),
#  ('in', 'thy'),
#  ('thy', 'hate'),
#  ('hate', '.'),
#  ('.', 'IAGO'),
#  ('IAGO', '.'),
#  ('.', 'Despise'),
#  ('Despise', 'me'),
#  ('me', ','),
#  (',', 'if'),
#  ('if', 'I'),
#  ('I', 'do'),
#  ('do', 'not'),
#  ('not', '.'),
#  ('.', 'Three'),
#  ('Three', 'great'),
#  ('great', 'ones'),
#  ('ones', 'of'),
#  ('of', 'the'),
#  ('the', 'city'),
#  ('city', ','),
#  (',', 'In'),
#  ('In', 'personal'),
#  ('personal', 'suit'),
#  ('suit', 'to'),
#  ('to', 'make'),
#  ('make', 'me'),
#  ('me', 'h')]

# %% [markdown]
# Why do bigrams matter? Typically it is in the context of some other analysis or relationship (i.e. some statistical learning module as a feature vector). They handicap your ability to do a direct analysis (two items instead of one); however, they expand your ability to model structure.
#
# There are a number of reasons and instances where you will want to rely on Xgrams instead of or in addition to the unigram bag of words approach in order to have a description of the text that takes structure into account. A common reason is when you have a multi-word concept that encodes meaning, which often happens in specialized fields/writing.
#
# Just because you perform the extraction as multiple words, doesn't mean that you cannot reduce the Xgram  to a single word token. For convenience in further processing these tokens will be joined as a single string like so:

# %%
['-'.join(x) for x in list(nltk.bigrams(wordlist))]
# Out:
# ['SCENE-:',
#  ':-Venice',
#  'Venice-and',
#  'and-Cyprus',
#  'Cyprus-ACT',
#  'ACT-I',
#  'I-.',
#  '.-SCENE',
#  'SCENE-I.',
#  'I.-Venice',
#  'Venice-.',
#  '.-A',
#  'A-street',
#  'street-.',
#  '.-Enter',
#  'Enter-Roderigo',
#  'Roderigo-and',
#  'and-Iago',
#  'Iago-.',
#  '.-RODERIGO',
#  'RODERIGO-.',
#  '.-Tush',
#  'Tush-,',
#  ',-never',
#  'never-tell',
#  'tell-me',
#  'me-!',
#  '!-I',
#  'I-take',
#  'take-it',
#  'it-much',
#  'much-unkindly',
#  'unkindly-That',
#  'That-thou',
#  'thou-,',
#  ',-Iago',
#  'Iago-,',
#  ',-who',
#  'who-hast',
#  'hast-had',
#  'had-my',
#  'my-purse',
#  'purse-As',
#  'As-if',
#  'if-the',
#  'the-strings',
#  'strings-were',
#  'were-thine',
#  'thine-,',
#  ',-shouldst',
#  'shouldst-know',
#  'know-of',
#  'of-this',
#  'this-.',
#  '.-IAGO',
#  'IAGO-.',
#  ".-'Sblood",
#  "'Sblood-,",
#  ',-but',
#  'but-you',
#  'you-will',
#  'will-not',
#  'not-hear',
#  'hear-me',
#  'me-.',
#  '.-If',
#  'If-ever',
#  'ever-I',
#  'I-did',
#  'did-dream',
#  'dream-of',
#  'of-such',
#  'such-a',
#  'a-matter',
#  'matter-,',
#  ',-Abhor',
#  'Abhor-me',
#  'me-.',
#  '.-RODERIGO',
#  'RODERIGO-.',
#  '.-Thou',
#  "Thou-told'st",
#  "told'st-me",
#  'me-thou',
#  'thou-didst',
#  'didst-hold',
#  'hold-him',
#  'him-in',
#  'in-thy',
#  'thy-hate',
#  'hate-.',
#  '.-IAGO',
#  'IAGO-.',
#  '.-Despise',
#  'Despise-me',
#  'me-,',
#  ',-if',
#  'if-I',
#  'I-do',
#  'do-not',
#  'not-.',
#  '.-Three',
#  'Three-great',
#  'great-ones',
#  'ones-of',
#  'of-the',
#  'the-city',
#  'city-,',
#  ',-In',
#  'In-personal',
#  'personal-suit',
#  'suit-to',
#  'to-make',
#  'make-me',
#  'me-h']

# %% [markdown]
# You wouldn't join unigrams and bigrams in a bag-of-words analysis, but you would do so in applications where you are generating features from the text.

# %% [markdown]
# # POS
#
# The final basic preprocessing step is determining the parts of speech. This is the lead in to may other machine learning techniques that leverage parts of speech to determine structure and novelty

# %%
nltk.pos_tag(nltk_regex.tokenize('The fox ran quickly to its prey'))

# %% [markdown]
# How does this work? The simple answer is that this is a pre-trained model built from an annotated corpus. Text from that corpus has been trained like so:
#
# `[[('today','NN'),('is','VBZ'),('good','JJ'),('day','NN')], [('yes','NNS'),('it','PRP'),('beautiful','JJ')]]`
#
# and the model takes that learning and makes predictions on newly submitted text. The NLTK pos_tagger is trained on The Wall Street Journal corpus (clear links to source here: https://stackoverflow.com/questions/32016545/how-does-nltk-pos-tag-work/41384824)

# %% [markdown]
# # Alternative Packages
#
# There are of course more modern alternatives to NLTK that rely on language models (as opposed to classical algorithms). While NLTK has trained models in it, it's not the core foundation of the package like these newer packages. The big packages would be:
#
# * spaCy
# * huggingface
#
# `huggingface` is really more of a package to make it easy to use and train LLMs, so it's not really a competitor to NLTK in a pure sense. `spaCy` is however a very opinionated library that mimics a lot of the core functionality in NLTK while being based on a language model.

# %%
# !conda install spacy -y
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.5.0
#     latest version: 25.7.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - spacy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     catalogue-2.0.10           |  py311h38be061_2          43 KB  conda-forge
#     cloudpathlib-0.22.0        |     pyhd8ed1ab_0          49 KB  conda-forge
#     confection-0.1.5           |     pyhecae5ae_0          37 KB  conda-forge
#     cymem-2.0.11               |  py311h1ddb823_1          53 KB  conda-forge
#     cython-blis-1.3.0          |  py311h9f3472d_0         7.8 MB  conda-forge
#     langcodes-3.4.1            |     pyhd8ed1ab_1         152 KB  conda-forge
#     language-data-1.3.0        |     pyhff2d567_0         4.0 MB  conda-forge
#     marisa-trie-1.2.1          |  py311hfdbb021_0         178 KB  conda-forge
#     markdown-it-py-4.0.0       |     pyhd8ed1ab_0          63 KB  conda-forge
#     mdurl-0.1.2                |     pyhd8ed1ab_1          14 KB  conda-forge
#     murmurhash-1.0.13          |  py311hc665b79_1          37 KB  conda-forge
#     preshed-3.0.9              |  py311hfdbb021_2         132 KB  conda-forge
#     rich-14.1.0                |     pyhe01879c_0         196 KB  conda-forge
#     shellingham-1.5.4          |     pyhd8ed1ab_1          14 KB  conda-forge
#     smart-open-7.3.1           |       h08b120a_0           5 KB  conda-forge
#     smart_open-7.3.1           |     pyhcf101f3_0          53 KB  conda-forge
#     spacy-3.8.7                |  py311h60b02de_0         5.7 MB  conda-forge
#     spacy-legacy-3.0.12        |     pyhd8ed1ab_0          28 KB  conda-forge
#     spacy-loggers-1.0.5        |     pyhd8ed1ab_0          21 KB  conda-forge
#     srsly-2.5.1                |  py311hfdbb021_1         600 KB  conda-forge
#     thinc-8.3.6                |  py311h60b02de_0         979 KB  conda-forge
#     typer-0.19.2               |     pyhef33e25_0          77 KB  conda-forge
#     typer-slim-0.19.2          |     pyhcf101f3_0          46 KB  conda-forge
#     typer-slim-standard-0.19.2 |       h6e3bb38_0           5 KB  conda-forge
#     ujson-5.11.0               |  py311hc665b79_1          58 KB  conda-forge
#     wasabi-1.1.3               |     pyhd8ed1ab_1          28 KB  conda-forge
#     weasel-0.4.1               |     pyhd8ed1ab_2          42 KB  conda-forge
#     wrapt-1.17.3               |  py311h49ec1c0_1          64 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        20.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   catalogue          conda-forge/linux-64::catalogue-2.0.10-py311h38be061_2
#   cloudpathlib       conda-forge/noarch::cloudpathlib-0.22.0-pyhd8ed1ab_0
#   confection         conda-forge/noarch::confection-0.1.5-pyhecae5ae_0
#   cymem              conda-forge/linux-64::cymem-2.0.11-py311h1ddb823_1
#   cython-blis        conda-forge/linux-64::cython-blis-1.3.0-py311h9f3472d_0
#   langcodes          conda-forge/noarch::langcodes-3.4.1-pyhd8ed1ab_1
#   language-data      conda-forge/noarch::language-data-1.3.0-pyhff2d567_0
#   marisa-trie        conda-forge/linux-64::marisa-trie-1.2.1-py311hfdbb021_0
#   markdown-it-py     conda-forge/noarch::markdown-it-py-4.0.0-pyhd8ed1ab_0
#   mdurl              conda-forge/noarch::mdurl-0.1.2-pyhd8ed1ab_1
#   murmurhash         conda-forge/linux-64::murmurhash-1.0.13-py311hc665b79_1
#   preshed            conda-forge/linux-64::preshed-3.0.9-py311hfdbb021_2
#   rich               conda-forge/noarch::rich-14.1.0-pyhe01879c_0
#   shellingham        conda-forge/noarch::shellingham-1.5.4-pyhd8ed1ab_1
#   smart-open         conda-forge/noarch::smart-open-7.3.1-h08b120a_0
#   smart_open         conda-forge/noarch::smart_open-7.3.1-pyhcf101f3_0
#   spacy              conda-forge/linux-64::spacy-3.8.7-py311h60b02de_0
#   spacy-legacy       conda-forge/noarch::spacy-legacy-3.0.12-pyhd8ed1ab_0
#   spacy-loggers      conda-forge/noarch::spacy-loggers-1.0.5-pyhd8ed1ab_0
#   srsly              conda-forge/linux-64::srsly-2.5.1-py311hfdbb021_1
#   thinc              conda-forge/linux-64::thinc-8.3.6-py311h60b02de_0
#   typer              conda-forge/noarch::typer-0.19.2-pyhef33e25_0
#   typer-slim         conda-forge/noarch::typer-slim-0.19.2-pyhcf101f3_0
#   typer-slim-standa~ conda-forge/noarch::typer-slim-standard-0.19.2-h6e3bb38_0
#   ujson              conda-forge/linux-64::ujson-5.11.0-py311hc665b79_1
#   wasabi             conda-forge/noarch::wasabi-1.1.3-pyhd8ed1ab_1
#   weasel             conda-forge/noarch::weasel-0.4.1-pyhd8ed1ab_2
#   wrapt              conda-forge/linux-64::wrapt-1.17.3-py311h49ec1c0_1
#
#
#
# Downloading and Extracting Packages:
# cython-blis-1.3.0    | 7.8 MB    |                                       |   0%
# spacy-3.8.7          | 5.7 MB    |                                       |   0%
#
# language-data-1.3.0  | 4.0 MB    |                                       |   0%
#
#
# thinc-8.3.6          | 979 KB    |                                       |   0%
#
#
#
# srsly-2.5.1          | 600 KB    |                                       |   0%
#
#
#
#
# rich-14.1.0          | 196 KB    |                                       |   0%
#
#
#
#
#
# marisa-trie-1.2.1    | 178 KB    |                                       |   0%
#
#
#
#
#
#
# langcodes-3.4.1      | 152 KB    |                                       |   0%
#
#
#
#
#
#
#
# preshed-3.0.9        | 132 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# typer-0.19.2         | 77 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
# wrapt-1.17.3         | 64 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# markdown-it-py-4.0.0 | 63 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# ujson-5.11.0         | 58 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# cymem-2.0.11         | 53 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# smart_open-7.3.1     | 53 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cloudpathlib-0.22.0  | 49 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# typer-slim-0.19.2    | 46 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# catalogue-2.0.10     | 43 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# weasel-0.4.1         | 42 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# murmurhash-1.0.13    | 37 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# confection-0.1.5     | 37 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# wasabi-1.1.3         | 28 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# spacy-legacy-3.0.12  | 28 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
# thinc-8.3.6          | 979 KB    | 6                                     |   2%
#
#
#
# cython-blis-1.3.0    | 7.8 MB    |                                       |   0%
#
# language-data-1.3.0  | 4.0 MB    | 1                                     |   0%
# cython-blis-1.3.0    | 7.8 MB    | #########4                            |  26%
#
# language-data-1.3.0  | 4.0 MB    | ##################8                   |  51%
#
#
#
#
# rich-14.1.0          | 196 KB    | ###                                   |   8%
# spacy-3.8.7          | 5.7 MB    | ###########7                          |  32%
#
#
#
#
#
# cython-blis-1.3.0    | 7.8 MB    | #############################3        |  79%
#
#
#
#
#
#
# langcodes-3.4.1      | 152 KB    | ###9                                  |  11%
#
#
#
#
#
#
#
# preshed-3.0.9        | 132 KB    | ####4                                 |  12%
#
#
#
#
#
#
#
#
# typer-0.19.2         | 77 KB     | #######7                              |  21%
#
#
#
#
#
#
#
#
#
# wrapt-1.17.3         | 64 KB     | #########2                            |  25%
#
#
#
#
#
#
#
#
#
#
#
# ujson-5.11.0         | 58 KB     | ##########1                           |  27%
#
#
#
#
# rich-14.1.0          | 196 KB    | ##################################### | 100%
#
#
#
#
# rich-14.1.0          | 196 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# markdown-it-py-4.0.0 | 63 KB     | #########3                            |  25%
#
#
#
#
#
#
#
#
#
#
#
#
# cymem-2.0.11         | 53 KB     | ###########1                          |  30%
#
#
#
#
#
# marisa-trie-1.2.1    | 178 KB    | ##################################### | 100%
#
#
#
#
#
# marisa-trie-1.2.1    | 178 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# smart_open-7.3.1     | 53 KB     | ###########1                          |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cloudpathlib-0.22.0  | 49 KB     | ############                          |  33%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# typer-slim-0.19.2    | 46 KB     | ############8                         |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# weasel-0.4.1         | 42 KB     | ##############2                       |  39%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# catalogue-2.0.10     | 43 KB     | #############7                        |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# murmurhash-1.0.13    | 37 KB     | ################                      |  43%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# confection-0.1.5     | 37 KB     | ################2                     |  44%
#
#
#
#
#
#
# langcodes-3.4.1      | 152 KB    | ##################################### | 100%
#
#
#
#
#
#
# langcodes-3.4.1      | 152 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# spacy-legacy-3.0.12  | 28 KB     | #####################1                |  57%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# wasabi-1.1.3         | 28 KB     | #####################                 |  57%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# srsly-2.5.1          | 600 KB    | ##################################### | 100%
#
#
#
# srsly-2.5.1          | 600 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# preshed-3.0.9        | 132 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# preshed-3.0.9        | 132 KB    | ##################################### | 100%
#
#
# thinc-8.3.6          | 979 KB    | ##################################### | 100%
#
#
# thinc-8.3.6          | 979 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# typer-0.19.2         | 77 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
# typer-0.19.2         | 77 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# wrapt-1.17.3         | 64 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# wrapt-1.17.3         | 64 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# ujson-5.11.0         | 58 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# ujson-5.11.0         | 58 KB     | ##################################### | 100%
#
# language-data-1.3.0  | 4.0 MB    | ##################################### | 100%
#
# language-data-1.3.0  | 4.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# markdown-it-py-4.0.0 | 63 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# markdown-it-py-4.0.0 | 63 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# cymem-2.0.11         | 53 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# cymem-2.0.11         | 53 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# smart_open-7.3.1     | 53 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# smart_open-7.3.1     | 53 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cloudpathlib-0.22.0  | 49 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cloudpathlib-0.22.0  | 49 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# typer-slim-0.19.2    | 46 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# typer-slim-0.19.2    | 46 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# weasel-0.4.1         | 42 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# weasel-0.4.1         | 42 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# catalogue-2.0.10     | 43 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-blis-1.3.0    | 7.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# murmurhash-1.0.13    | 37 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# murmurhash-1.0.13    | 37 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# confection-0.1.5     | 37 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# confection-0.1.5     | 37 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# wasabi-1.1.3         | 28 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# wasabi-1.1.3         | 28 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# spacy-legacy-3.0.12  | 28 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# spacy-legacy-3.0.12  | 28 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# spacy-3.8.7          | 5.7 MB    | ##################################### | 100%
# spacy-3.8.7          | 5.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# and then we need to download a language model to use

# %%
# !python -m spacy download en
# Out:
# ⚠ As of spaCy v3.0, shortcuts like 'en' are deprecated. Please use the
# full pipeline package name 'en_core_web_sm' instead.
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 70.3 MB/s eta 0:00:0000:0100:01
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# Now we can use the package and the downloaded language model

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

fulltext = open('../../data/Othello.txt').read()
#We have spacy process the text into a document
doc = nlp(fulltext[:500])
doc
# Out:
# SCENE: Venice and Cyprus
#
# ACT I. SCENE I.
# Venice. A street.
#
# Enter Roderigo and Iago.
#
#   RODERIGO. Tush, never tell me! I take it much unkindly
#     That thou, Iago, who hast had my purse
#     As if the strings were thine, shouldst know of this.
#   IAGO. 'Sblood, but you will not hear me.
#     If ever I did dream of such a matter,
#     Abhor me.
#   RODERIGO. Thou told'st me thou didst hold him in thy hate.
#   IAGO. Despise me, if I do not. Three great ones of the city,
#     In personal suit to make me h

# %%
#We can get out sentences
for sentence in doc.sents:
    print(sentence)
# Out:
# SCENE:
# Venice and Cyprus
#
# ACT I. SCENE I.
# Venice.
# A street.
#
#
# Enter Roderigo and Iago.
#
#   RODERIGO.
# Tush, never tell me!
# I take it much unkindly
#     That thou, Iago, who hast had my purse
#
# As if the strings were thine, shouldst know of this.
#   IAGO.
# '
# Sblood, but you will not hear me.
#
# If ever I did dream of such a matter,
#     Abhor me.
#
# RODERIGO.
# Thou told'st me thou didst
# hold him in thy hate.
#
# IAGO.
# Despise me, if I do not.
# Three great ones of the city,
#     In personal suit to make me h

# %%
#Or noun chunks
for nchunk in doc.noun_chunks:
    print(nchunk)
# Out:
# SCENE
# Venice
# Cyprus
#
# ACT I. SCENE I.
# Venice
# A street
# Enter Roderigo
# Iago
# RODERIGO
# Tush
# me
# I
# it
# Iago
# who
# hast
# my purse
# the strings
# shouldst know
# this
# IAGO
# Sblood
# you
# me
# I
# dream
# such a matter
# me
# RODERIGO
# Thou told'st
# me
# thou didst
# him
# thy hate
# IAGO
# me
# I
# Three great ones
# the city
# personal suit
# me

# %%
#We can look at our tokens
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# SCENE NOUN ROOT
# : PUNCT punct
# Venice PROPN ROOT
# and CCONJ cc
# Cyprus PROPN compound
#
#
#  SPACE dep
# ACT PROPN compound
# I. PROPN compound
# SCENE PROPN compound
# I. PROPN compound
#
#  SPACE dep
# Venice PROPN conj
# . PUNCT punct
# A DET det
# street NOUN ROOT
# . PUNCT punct
#
#
#  SPACE dep
# Enter PROPN compound
# Roderigo PROPN ROOT
# and CCONJ cc
# Iago PROPN conj
# . PUNCT punct
#
#
#    SPACE dep
# RODERIGO PROPN appos
# . PUNCT punct
# Tush NOUN nsubj
# , PUNCT punct
# never ADV neg
# tell VERB ROOT
# me PRON dobj
# ! PUNCT punct
# I PRON nsubj
# take VERB ROOT
# it PRON dobj
# much ADV advmod
# unkindly ADV advmod
#
#      SPACE dep
# That DET det
# thou NOUN punct
# , PUNCT punct
# Iago PROPN appos
# , PUNCT punct
# who PRON nsubj
# hast NOUN nsubj
# had VERB relcl
# my PRON poss
# purse NOUN dobj
#
#      SPACE dep
# As SCONJ mark
# if SCONJ mark
# the DET det
# strings NOUN nsubj
# were AUX ROOT
# thine ADJ acomp
# , PUNCT punct
# shouldst ADJ amod
# know NOUN appos
# of ADP prep
# this PRON pobj
# . PUNCT punct
#
#    SPACE dep
# IAGO PROPN attr
# . PUNCT punct
# ' PUNCT ROOT
# Sblood PROPN ROOT
# , PUNCT punct
# but CCONJ cc
# you PRON nsubj
# will AUX aux
# not PART neg
# hear VERB conj
# me PRON dobj
# . PUNCT punct
#
#      SPACE dep
# If SCONJ mark
# ever ADV pcomp
# I PRON nsubj
# did VERB advcl
# dream NOUN dobj
# of ADP prep
# such DET predet
# a DET det
# matter NOUN pobj
# , PUNCT punct
#
#      SPACE dep
# Abhor VERB ROOT
# me PRON dobj
# . PUNCT punct
#
#    SPACE dep
# RODERIGO PROPN ROOT
# . PUNCT punct
# Thou PROPN compound
# told'st NOUN ROOT
# me PRON appos
# thou PROPN compound
# didst NOUN appos
# hold VERB ROOT
# him PRON dobj
# in ADP prep
# thy PRON poss
# hate NOUN pobj
# . PUNCT punct
#
#    SPACE dep
# IAGO PROPN ROOT
# . PUNCT punct
# Despise VERB ROOT
# me PRON dobj
# , PUNCT punct
# if SCONJ mark
# I PRON nsubj
# do VERB advcl
# not PART neg
# . PUNCT punct
# Three NUM nummod
# great ADJ amod
# ones NOUN nsubj
# of ADP prep
# the DET det
# city NOUN pobj
# , PUNCT punct
#
#      SPACE dep
# In ADP prep
# personal ADJ amod
# suit NOUN pobj
# to PART aux
# make VERB advcl
# me PRON dobj
# h VERB ROOT

# %%
#And our statistically predicted entities
for ent in doc.ents:
    print(ent, ent.label_)
# Out:
# Venice GPE
# I. SCENE I.
#  ORG
# Venice GPE
# Roderigo PERSON
# Iago ORG
# RODERIGO ORG
# Tush PERSON
# Sblood PERSON
# Three CARDINAL

# %% [markdown]
# spacy can also handle modern web text (i.e. emojis) which are a massive pain to do manually

# %%
doc = nlp("Pensive emoji is where it has always been. Pensive is the superior "
          "emoji. It's outranking happy 😔 ")
print(doc[0].text)          
print(doc[1].text)          
print(doc[-1].text)         
print(doc[17:19].text)      

noun_chunks = list(doc.noun_chunks)
print(noun_chunks[0].text)  

sentences = list(doc.sents)
print(sentences[1].text)
# Out:
# Pensive
# emoji
# 😔
# outranking happy
# Pensive emoji
# Pensive is the superior emoji.
